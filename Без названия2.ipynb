# %%
import csv, sqlite3
con = sqlite3.connect("Exercises.db")
cur = con.cursor()
# %load_ext sql
# %sql sqlite:///Exercises.db

# %%
import pandas as pd 
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCensusData.csv")
df.to_sql("CENSUS_DATA", con, if_exists='replace', index=False,method="multi")
df
# Out:
#     COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                     1.0         Rogers Park                         7.7
# 1                     2.0          West Ridge                         7.8
# 2                     3.0              Uptown                         3.8
# 3                     4.0      Lincoln Square                         3.4
# 4                     5.0        North Center                         0.3
# ..                    ...                 ...                         ...
# 73                   74.0     Mount Greenwood                         1.0
# 74                   75.0         Morgan Park                         0.8
# 75                   76.0              O'Hare                         3.6
# 76                   77.0           Edgewater                         4.1
# 77                    NaN             CHICAGO                         4.7
#
#     PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# ...

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/FinalModule_Coursera_V5/data/ChicagoCrimeData.csv")
df.to_sql("CHICAGO_CRIME_DATA", con, if_exists='replace', index=False, method="multi")
df
# Out:
#            ID CASE_NUMBER        DATE                     BLOCK  IUCR  \
# 0     3512276    HK587712  2004-08-28        047XX S KEDZIE AVE   890
# 1     3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE   820
# 2     8002131    HT233595  2011-04-04        043XX S WABASH AVE   820
# 3     7903289    HT133522  2010-12-30      083XX S KINGSTON AVE   840
# 4    10402076    HZ138551  2016-02-02           033XX W 66TH ST   820
# ..        ...         ...         ...                       ...   ...
# 528  10453948    HZ192829  2016-03-01           028XX E 79TH ST  1055
# 529  10397129    HZ133234  2016-01-29       006XX W HARRISON ST  5114
# 530   3269495    HJ747227  2003-11-08           012XX W 81ST ST   510
# 531  10840565    JA143710  2017-02-06        009XX N KARLOV AVE  5073
# 532   1326195     G021609  2001-01-11       087XX S ESCANABA AV  9901
#
#                          PRIMARY_TYPE  \
# 0                               THEFT
# 1                               THEFT
# ...

# %%
 # %sql SELECT * FROM CHICAGO_CRIME_DATA WHERE "IUCR" > 900
# Out:
#  * sqlite:///Exercises.db
# Done.
# [(10268156, 'HY455377', '2015-08-31', '072XX S WOOD ST', '910', 'MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'STREET', 0, 0, 735, 7, 17.0, 67.0, '7', 1165601.0, 1856776.0, 2015, 41.76258082, -87.66860929, '(41.762580818, -87.66860929)'),
#  (6672913, 'HP747058', '2008-12-22', '065XX S NORMAL BLVD', '910', 'MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'STREET', 0, 0, 722, 7, 20.0, 68.0, '7', 1174217.0, 1861584.0, 2008, 41.77558748, -87.63688771, '(41.775587482, -87.636887705)'),
#  (5835389, 'HN645348', '2007-10-12', '032XX W CULLOM AVE', '910', 'MOTOR VEHICLE THEFT', 'AUTOMOBILE', 'STREET', 0, 0, 1724, 17, 33.0, 16.0, '7', 1153808.0, 1928395.0, 2007, 41.95935337, -87.70992679, '(41.95935337, -87.709926786)'),
#  (3969617, 'HL334216', '2005-05-03', '085XX S CRANDON AVE', '930', 'MOTOR VEHICLE THEFT', 'THEFT/RECOVERY: AUTOMOBILE', 'STREET', 0, 0, 412, 4, 8.0, 46.0, '7', 1192986.0, 1848936.0, 2005, 41.74044266, -87.56849579, '(41.740442663, -87.568495789)'),
# ...

# %%
## type in your query to retrieve list of all tables in the database
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///Exercises.db
# Done.
# [('CHICAGO_CRIME_DATA',), ('CENSUS_DATA',), ('CHICAGO_PUBLIC_SCHOOLS_DATA',)]

# %%
# type in your query to retrieve the number of columns in the SCHOOLS table
# %sql SELECT count(*) FROM CHICAGO_CRIME_DATA;
# Out:
#  * sqlite:///Exercises.db
# Done.
# [(533,)]

# %%
#How many case numbers in dataset 
# %sql select count(*) from  CHICAGO_CRIME_DATA where CASE_NUMBER = 'G652158'
# Out:
#  * sqlite:///Exercises.db
# Done.
# [(1,)]

# %%
# %sql select MAX(IUCR) AS MAX_IUCR from  CHICAGO_CRIME_DATA
# Out:
#  * sqlite:///Exercises.db
# Done.
# [('9901',)]

# %%
# %sql select DESCRIPTION AS DESC from  CHICAGO_CRIME_DATA WHERE IUCR = 9901
# Out:
#  * sqlite:///Exercises.db
# Done.
# [('DOMESTIC VIOLENCE',)]

# %%
#What are the top 10 descriptions
# %sql select ID, DESCRIPTION FROM CHICAGO_CRIME_DATA ORDER BY IUCR DESC nulls last limit 10
# Out:
#  * sqlite:///Exercises.db
# Done.
# [(1326195, 'DOMESTIC VIOLENCE'),
#  (3969617, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (3072896, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (2859254, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (9651438, 'ATT: AUTOMOBILE'),
#  (2316019, 'TRUCK, BUS, MOTOR HOME'),
#  (10268156, 'AUTOMOBILE'),
#  (6672913, 'AUTOMOBILE'),
#  (5835389, 'AUTOMOBILE'),
#  (7427845, 'AUTOMOBILE')]

# %%
# %%sql
# select hardship_index from CENSUS_DATA CD, CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# where CD.community_area_number = CPS.community_area_number
# and college_enrollment = 4368
# Out:
#  * sqlite:///Exercises.db
# (sqlite3.OperationalError) no such column: hardship_index
# [SQL: select hardship_index from CENSUS_DATA CD, CHICAGO_PUBLIC_SCHOOLS_DATA CPS
# where CD.community_area_number = CPS.community_area_number
# and college_enrollment = 4368]
# (Background on this error at: http://sqlalche.me/e/e3q8)
