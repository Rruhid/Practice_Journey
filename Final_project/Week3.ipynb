# %%
import pandas as pd
import seaborn as sns 
df = pd.read_csv("m1_survey_data.csv")
df.head()
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
# 2          13  I am a developer by profession      Yes
# 3          16  I am a developer by profession      Yes
# 4          17  I am a developer by profession      Yes
#
#                                          OpenSourcer  \
# 0                                              Never
# 1                         Once a month or more often
# 2  Less than once a month but more than once per ...
# 3                                              Never
# 4  Less than once a month but more than once per ...
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
# 2  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 3  The quality of OSS and closed source software ...  Employed full-time
# 4  The quality of OSS and closed source software ...  Employed full-time
#
#           Country Student                                            EdLevel  \
# 0   United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1     New Zealand      No  Some college/university study without earning ...
# 2   United States      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 3  United Kingdom      No        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 4       Australia      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
# 2  Computer science, computer engineering, or sof...  ...
# 3                                                NaN  ...
# 4  Computer science, computer engineering, or sof...  ...
#
#                               WelcomeChange  \
# 0   Just as welcome now as I felt last year
# 1   Just as welcome now as I felt last year
# 2  Somewhat more welcome now than last year
# 3   Just as welcome now as I felt last year
# 4   Just as welcome now as I felt last year
#
#                                         SONewContent   Age Gender Trans  \
# 0  Tech articles written by other developers;Indu...  22.0    Man    No
# 1                                                NaN  23.0    Man    No
# 2  Tech articles written by other developers;Cour...  28.0    Man    No
# 3  Tech articles written by other developers;Indu...  26.0    Man    No
# 4  Tech articles written by other developers;Indu...  29.0    Man    No
#
#                  Sexuality                              Ethnicity Dependents  \
# 0  Straight / Heterosexual           White or of European descent         No
# 1                 Bisexual           White or of European descent         No
# 2  Straight / Heterosexual           White or of European descent        Yes
# 3  Straight / Heterosexual           White or of European descent         No
# 4  Straight / Heterosexual  Hispanic or Latino/Latina;Multiracial         No
#
#             SurveyLength                  SurveyEase
# 0  Appropriate in length                        Easy
# 1  Appropriate in length  Neither easy nor difficult
# 2  Appropriate in length                        Easy
# 3  Appropriate in length  Neither easy nor difficult
# 4  Appropriate in length                        Easy
#
# [5 rows x 85 columns]

# %%
#Plot the distribution curve for the column ConvertedComp.
df['ConvertedComp']
# Out:
# 0         61000.0
# 1         95179.0
# 2         90000.0
# 3        455352.0
# 4         65277.0
#            ...
# 11547    130000.0
# 11548     19880.0
# 11549    105000.0
# 11550     80371.0
# 11551         NaN
# Name: ConvertedComp, Length: 11552, dtype: float64

# %%
df['Age'].median()
# Out:
# 29.0

# %%
df['ConvertedComp'].isna().sum()
# Out:
# 822

# %%
sns.histplot(df['ConvertedComp'], kde = True)
# Out:
# <AxesSubplot:xlabel='ConvertedComp', ylabel='Count'>

# %%
#Plot the histogram for the column ConvertedComp.
import matplotlib as mpl 
# %matplotlib inline  
import matplotlib.pyplot as plt  
plt.hist(df['ConvertedComp'])
# Out:
# (array([9793.,  244.,  117.,  127.,  101.,  131.,   34.,   15.,   15.,
#          153.]),
#  array([      0.,  200000.,  400000.,  600000.,  800000., 1000000.,
#         1200000., 1400000., 1600000., 1800000., 2000000.]),
#  <BarContainer object of 10 artists>)

# %%
#What is the median of the column ConvertedComp?
df['ConvertedComp'].dropna(axis=0, inplace=True)

# %%
df['ConvertedComp'].isnull().sum()
# Out:
# 822

# %%
print('Median is',df['ConvertedComp'].median())
# Out:
# Median is 57744.0

# %%
df['ConvertedComp'].fillna('57744.0', inplace=True)

# %%
df['ConvertedComp'].isnull().sum()
# Out:
# 0

# %%
#How many responders identified themselves only as a Man? 
df['Gender'].value_counts()
# Out:
# Man                                                            10626
# Woman                                                            737
# Non-binary, genderqueer, or gender non-conforming                 63
# Man;Non-binary, genderqueer, or gender non-conforming             26
# Woman;Non-binary, genderqueer, or gender non-conforming           14
# Woman;Man                                                          9
# Woman;Man;Non-binary, genderqueer, or gender non-conforming        2
# Name: Gender, dtype: int64

# %%
df['ConvertedComp'].value_counts()
# Out:
# 57744.0      822
# 2000000.0    140
# 1000000.0    105
# 100000.0     105
# 150000.0      94
#             ...
# 12612.0        1
# 95179.0        1
# 114168.0       1
# 40100.0        1
# 19880.0        1
# Name: ConvertedComp, Length: 3516, dtype: int64

# %%
 # your code goes here 
df.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
#        'BlockchainOrg', 'BlockchainIs', 'BetterLife', 'ITperson', 'OffOn',
#        'SocialMedia', 'Extraversion', 'ScreenName', 'SOVisit1st',
#        'SOVisitFreq', 'SOVisitTo', 'SOFindAnswer', 'SOTimeSaved',
#        'SOHowMuchTime', 'SOAccount', 'SOPartFreq', 'SOJobs', 'EntTeams',
#        'SOComm', 'WelcomeChange', 'SONewContent', 'Age', 'Gender', 'Trans',
#        'Sexuality', 'Ethnicity', 'Dependents', 'SurveyLength', 'SurveyEase'],
#       dtype='object')

# %%
# Find out the median ConvertedComp of responders identified themselves only as a Woman?
df_woman = df[df['Gender'] == 'Woman']
df_woman
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 30             71                     I am a developer by profession      Yes
# 32             75                     I am a developer by profession      Yes
# 38             86  I am not primarily a developer, but I write co...      Yes
# 45            100                     I am a developer by profession      Yes
# 68            148                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 11464       24943                     I am a developer by profession      Yes
# 11484       24998                     I am a developer by profession       No
# 11497       25017                     I am a developer by profession      Yes
# 11525       25088                     I am a developer by profession      Yes
# 11539       25120                     I am a developer by profession      Yes
#
#                       OpenSourcer  \
# 30                          Never
# 32                          Never
# 38     Once a month or more often
# 45     Once a month or more often
# 68                          Never
# ...                           ...
# 11464     Less than once per year
# 11484                       Never
# 11497     Less than once per year
# 11525                       Never
# 11539     Less than once per year
#
#                                               OpenSource          Employment  \
# 30     The quality of OSS and closed source software ...  Employed full-time
# 32     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 38     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 45     The quality of OSS and closed source software ...  Employed full-time
# 68     The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 11464  The quality of OSS and closed source software ...  Employed full-time
# 11484  OSS is, on average, of LOWER quality than prop...  Employed full-time
# 11497  The quality of OSS and closed source software ...  Employed full-time
# 11525  The quality of OSS and closed source software ...  Employed full-time
# 11539  OSS is, on average, of HIGHER quality than pro...  Employed full-time
#
#               Country         Student  \
# 30        Philippines              No
# 32              India  Yes, full-time
# 38              China              No
# 45             Canada              No
# 68      United States              No
# ...               ...             ...
# 11464           China  Yes, full-time
# 11484  United Kingdom              No
# 11497   United States              No
# 11525   United States              No
# 11539       Argentina  Yes, part-time
#
#                                                  EdLevel  \
# 30              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 32              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 38     Some college/university study without earning ...
# 45     Some college/university study without earning ...
# 68              Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                                  ...
# 11464           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11484           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11497        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 11525           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11539           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                           UndergradMajor  ...  \
# 30     Computer science, computer engineering, or sof...  ...
# 32     Computer science, computer engineering, or sof...  ...
# 38     Information systems, information technology, o...  ...
# 45     Computer science, computer engineering, or sof...  ...
# 68     Computer science, computer engineering, or sof...  ...
# ...                                                  ...  ...
# 11464  Computer science, computer engineering, or sof...  ...
# 11484  Computer science, computer engineering, or sof...  ...
# 11497  Computer science, computer engineering, or sof...  ...
# 11525  Fine arts or performing arts (ex. graphic desi...  ...
# 11539  Computer science, computer engineering, or sof...  ...
#
#                                   WelcomeChange  \
# 30        A lot more welcome now than last year
# 32      Just as welcome now as I felt last year
# 38     Somewhat more welcome now than last year
# 45      Just as welcome now as I felt last year
# 68      Just as welcome now as I felt last year
# ...                                         ...
# 11464   Just as welcome now as I felt last year
# 11484   Just as welcome now as I felt last year
# 11497   Just as welcome now as I felt last year
# 11525   Just as welcome now as I felt last year
# 11539   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 30     Tech articles written by other developers;Tech...  21.0  Woman    No
# 32          Courses on technologies you're interested in  27.0  Woman    No
# 38     Tech articles written by other developers;Indu...  26.0  Woman    No
# 45                                                   NaN  39.0  Woman    No
# 68                                                   NaN  28.0  Woman    No
# ...                                                  ...   ...    ...   ...
# 11464  Tech articles written by other developers;Indu...  25.0  Woman    No
# 11484  Tech articles written by other developers;Indu...  23.0  Woman    No
# 11497                                                NaN  32.0  Woman    No
# 11525                                                NaN  28.0  Woman    No
# 11539       Courses on technologies you're interested in  32.0  Woman    No
#
#                               Sexuality  \
# 30              Straight / Heterosexual
# 32              Straight / Heterosexual
# 38              Straight / Heterosexual
# 45                             Bisexual
# 68                       Gay or Lesbian
# ...                                 ...
# 11464           Straight / Heterosexual
# 11484  Bisexual;Straight / Heterosexual
# 11497                               NaN
# 11525                          Bisexual
# 11539           Straight / Heterosexual
#
#                                                Ethnicity Dependents  \
# 30                                East Asian;South Asian         No
# 32                                                   NaN         No
# 38                                                   NaN        Yes
# 45                          White or of European descent         No
# 68                           Black or of African descent         No
# ...                                                  ...        ...
# 11464                                         East Asian        Yes
# 11484                       White or of European descent         No
# 11497  East Asian;Native American, Pacific Islander, ...         No
# 11525  Black or of African descent;White or of Europe...        Yes
# 11539  Hispanic or Latino/Latina;White or of European...         No
#
#                 SurveyLength                  SurveyEase
# 30     Appropriate in length                        Easy
# 32                  Too long  Neither easy nor difficult
# 38                  Too long  Neither easy nor difficult
# 45     Appropriate in length                        Easy
# 68     Appropriate in length  Neither easy nor difficult
# ...                      ...                         ...
# 11464               Too long                        Easy
# 11484               Too long                        Easy
# 11497  Appropriate in length                        Easy
# 11525  Appropriate in length                        Easy
# 11539               Too long  Neither easy nor difficult
#
# [737 rows x 85 columns]

# %%
df_c = df[df['ConvertedComp'] == 100000.0]
df_c
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 12             29                     I am a developer by profession      Yes
# 49            110                     I am a developer by profession      Yes
# 167           364                     I am a developer by profession      Yes
# 257           578                     I am a developer by profession      Yes
# 589          1254                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 10851       23492  I am not primarily a developer, but I write co...       No
# 10905       23600                     I am a developer by profession      Yes
# 10945       23712                     I am a developer by profession      Yes
# 11076       24017                     I am a developer by profession       No
# 11281       24507                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 12     Less than once a month but more than once per ...
# 49                            Once a month or more often
# 167                           Once a month or more often
# 257    Less than once a month but more than once per ...
# 589    Less than once a month but more than once per ...
# ...                                                  ...
# 10851                                              Never
# 10905  Less than once a month but more than once per ...
# 10945                                              Never
# 11076                                              Never
# 11281                            Less than once per year
#
#                                               OpenSource          Employment  \
# 12     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 49     OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 167    OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 257    OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 589    The quality of OSS and closed source software ...  Employed full-time
# ...                                                  ...                 ...
# 10851  The quality of OSS and closed source software ...  Employed full-time
# 10905  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 10945  OSS is, on average, of HIGHER quality than pro...  Employed full-time
# 11076  The quality of OSS and closed source software ...  Employed full-time
# 11281  The quality of OSS and closed source software ...  Employed full-time
#
#              Country Student  \
# 12     United States      No
# 49     United States      No
# 167    United States      No
# 257    United States      No
# 589    United States      No
# ...              ...     ...
# 10851  United States      No
# 10905  United States      No
# 10945  United States      No
# 11076  United States      No
# 11281  United States      No
#
#                                                  EdLevel  \
# 12              Bachelor’s degree (BA, BS, B.Eng., etc.)
# 49           Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 167    Some college/university study without earning ...
# 257             Bachelor’s degree (BA, BS, B.Eng., etc.)
# 589    Secondary school (e.g. American high school, G...
# ...                                                  ...
# 10851           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10905           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 10945           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11076           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11281  Some college/university study without earning ...
#
#                                           UndergradMajor  ...  \
# 12                                                   NaN  ...
# 49     Computer science, computer engineering, or sof...  ...
# 167                             I never declared a major  ...
# 257    Computer science, computer engineering, or sof...  ...
# 589                                                  NaN  ...
# ...                                                  ...  ...
# 10851  A business discipline (ex. accounting, finance...  ...
# 10905  Information systems, information technology, o...  ...
# 10945  Computer science, computer engineering, or sof...  ...
# 11076  Computer science, computer engineering, or sof...  ...
# 11281                           I never declared a major  ...
#
#                                   WelcomeChange  \
# 12      Just as welcome now as I felt last year
# 49      Just as welcome now as I felt last year
# 167    Somewhat more welcome now than last year
# 257     Just as welcome now as I felt last year
# 589     Just as welcome now as I felt last year
# ...                                         ...
# 10851                                       NaN
# 10905   Just as welcome now as I felt last year
# 10945   Just as welcome now as I felt last year
# 11076   Just as welcome now as I felt last year
# 11281   Just as welcome now as I felt last year
#
#                                             SONewContent   Age Gender Trans  \
# 12     Tech articles written by other developers;Cour...  32.0    Man    No
# 49     Industry news about technologies you're intere...  26.0    Man    No
# 167    Tech articles written by other developers;Indu...  40.0    Man    No
# 257                                                  NaN  28.0    Man    No
# 589            Tech articles written by other developers  37.0    Man    No
# ...                                                  ...   ...    ...   ...
# 10851  Tech meetups or events in your area;Courses on...  25.0    Man    No
# 10905          Tech articles written by other developers  30.0    Man    No
# 10945  Tech articles written by other developers;Tech...  32.0    Man    No
# 11076  Tech articles written by other developers;Indu...  25.0    Man    No
# 11281       Courses on technologies you're interested in  32.0    Man    No
#
#                               Sexuality  \
# 12              Straight / Heterosexual
# 49              Straight / Heterosexual
# 167             Straight / Heterosexual
# 257             Straight / Heterosexual
# 589    Bisexual;Straight / Heterosexual
# ...                                 ...
# 10851           Straight / Heterosexual
# 10905           Straight / Heterosexual
# 10945           Straight / Heterosexual
# 11076           Straight / Heterosexual
# 11281                               NaN
#
#                                                Ethnicity Dependents  \
# 12                          White or of European descent        Yes
# 49                                           South Asian         No
# 167                         White or of European descent        Yes
# 257    Black or of African descent;Hispanic or Latino...         No
# 589                         White or of European descent         No
# ...                                                  ...        ...
# 10851                       White or of European descent         No
# 10905                       White or of European descent         No
# 10945                       White or of European descent         No
# 11076                                         East Asian         No
# 11281  Hispanic or Latino/Latina;White or of European...        Yes
#
#                 SurveyLength                  SurveyEase
# 12     Appropriate in length                        Easy
# 49                  Too long                        Easy
# 167    Appropriate in length                        Easy
# 257    Appropriate in length                        Easy
# 589    Appropriate in length                        Easy
# ...                      ...                         ...
# 10851  Appropriate in length  Neither easy nor difficult
# 10905  Appropriate in length                        Easy
# 10945  Appropriate in length                        Easy
# 11076  Appropriate in length                        Easy
# 11281  Appropriate in length                        Easy
#
# [105 rows x 85 columns]

# %%
print('Woman median',df_woman['ConvertedComp'].median())
# Out:
# Woman median 57744.0

# %%
#Give the five number summary for the column Age? 
df['Age'].describe()
# Out:
# count    11255.000000
# mean        30.772394
# std          7.392780
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %%
df['Age']
# Out:
# 0        22.0
# 1        23.0
# 2        28.0
# 3        26.0
# 4        29.0
#          ...
# 11547    36.0
# 11548    25.0
# 11549    34.0
# 11550    25.0
# 11551    30.0
# Name: Age, Length: 11552, dtype: float64

# %%
plt.hist(df['Age'])
# Out:
# (array([2.127e+03, 5.400e+03, 2.588e+03, 8.590e+02, 2.250e+02, 4.900e+01,
#         6.000e+00, 0.000e+00, 0.000e+00, 1.000e+00]),
#  array([16. , 24.3, 32.6, 40.9, 49.2, 57.5, 65.8, 74.1, 82.4, 90.7, 99. ]),
#  <BarContainer object of 10 artists>)

# %%
import numpy as np
# your code goes here
df_cv = pd.DataFrame(data=df['ConvertedComp'])
df['ConvertedComp'] = pd.to_numeric(df['ConvertedComp'])

#df['ConvertedComp']= df['ConvertedComp'].astype(float)

df_cv.plot(kind='box', figsize=(8,6))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11552 entries, 0 to 11551
# Data columns (total 85 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Respondent              11552 non-null  int64
#  1   MainBranch              11552 non-null  object
#  2   Hobbyist                11552 non-null  object
#  3   OpenSourcer             11552 non-null  object
#  4   OpenSource              11471 non-null  object
#  5   Employment              11552 non-null  object
#  6   Country                 11552 non-null  object
#  7   Student                 11499 non-null  object
#  8   EdLevel                 11436 non-null  object
#  9   UndergradMajor          10812 non-null  object
#  10  EduOther                11388 non-null  object
#  11  OrgSize                 11454 non-null  object
#  12  DevType                 11485 non-null  object
#  13  YearsCode               11543 non-null  object
#  14  Age1stCode              11539 non-null  object
#  15  YearsCodePro            11536 non-null  object
#  16  CareerSat               11552 non-null  object
#  17  JobSat                  11551 non-null  object
#  18  MgrIdiot                11054 non-null  object
#  19  MgrMoney                11050 non-null  object
#  20  MgrWant                 11054 non-null  object
#  21  JobSeek                 11552 non-null  object
#  22  LastHireDate            11552 non-null  object
#  23  LastInt                 11129 non-null  object
#  24  FizzBuzz                11515 non-null  object
#  25  JobFactors              11549 non-null  object
#  26  ResumeUpdate            11511 non-null  object
#  27  CurrencySymbol          11552 non-null  object
#  28  CurrencyDesc            11552 non-null  object
#  29  CompTotal               10737 non-null  float64
#  30  CompFreq                11346 non-null  object
#  31  ConvertedComp           11552 non-null  object
#  32  WorkWeekHrs             11427 non-null  float64
#  33  WorkPlan                11429 non-null  object
#  34  WorkChallenge           11384 non-null  object
#  35  WorkRemote              11544 non-null  object
#  36  WorkLoc                 11520 non-null  object
#  37  ImpSyn                  11547 non-null  object
#  38  CodeRev                 11551 non-null  object
#  39  CodeRevHrs              9083 non-null   float64
#  40  UnitTests               11523 non-null  object
#  41  PurchaseHow             11354 non-null  object
#  42  PurchaseWhat            11514 non-null  object
#  43  LanguageWorkedWith      11541 non-null  object
#  44  LanguageDesireNextYear  11415 non-null  object
#  45  DatabaseWorkedWith      11096 non-null  object
#  46  DatabaseDesireNextYear  10497 non-null  object
#  47  PlatformWorkedWith      11130 non-null  object
#  48  PlatformDesireNextYear  10991 non-null  object
#  49  WebFrameWorkedWith      10139 non-null  object
#  50  WebFrameDesireNextYear  9918 non-null   object
#  51  MiscTechWorkedWith      9343 non-null   object
#  52  MiscTechDesireNextYear  10078 non-null  object
#  53  DevEnviron              11523 non-null  object
#  54  OpSys                   11518 non-null  object
#  55  Containers              11470 non-null  object
#  56  BlockchainOrg           9198 non-null   object
#  57  BlockchainIs            8915 non-null   object
#  58  BetterLife              11452 non-null  object
#  59  ITperson                11517 non-null  object
#  60  OffOn                   11514 non-null  object
#  61  SocialMedia             11251 non-null  object
#  62  Extraversion            11532 non-null  object
#  63  ScreenName              11039 non-null  object
#  64  SOVisit1st              11227 non-null  object
#  65  SOVisitFreq             11547 non-null  object
#  66  SOVisitTo               11551 non-null  object
#  67  SOFindAnswer            11549 non-null  object
#  68  SOTimeSaved             11501 non-null  object
#  69  SOHowMuchTime           9616 non-null   object
#  70  SOAccount               11551 non-null  object
#  71  SOPartFreq              10404 non-null  object
#  72  SOJobs                  11546 non-null  object
#  73  EntTeams                11547 non-null  object
#  74  SOComm                  11552 non-null  object
#  75  WelcomeChange           11463 non-null  object
#  76  SONewContent            9557 non-null   object
#  77  Age                     11255 non-null  float64
#  78  Gender                  11477 non-null  object
#  79  Trans                   11429 non-null  object
#  80  Sexuality               11005 non-null  object
#  81  Ethnicity               10869 non-null  object
#  82  Dependents              11408 non-null  object
#  83  SurveyLength            11533 non-null  object
#  84  SurveyEase              11538 non-null  object
# dtypes: float64(4), int64(1), object(80)
# memory usage: 7.5+ MB

# %%
#Find out the Inter Quartile Range for the column ConvertedComp.
# your code goes here
df['ConvertedComp'].dropna(axis=0,inplace=True) 
Q1,Q3=df['ConvertedComp'].quantile(.25),df['ConvertedComp'].quantile(.75)
IQR=Q3 - Q1
print('The Inter Quartile Range for ConvertedComp:', IQR)
# Out:
# The Inter Quartile Range for ConvertedComp: 0.0

# %%
#Find out the upper and lower bounds.

# your code goes here
upper=Q3+(IQR*1.5)
lower=Q1-(IQR*1.5)

print('Upper Bound:', upper)
print('Lower Bound:', lower)
# Out:
# Upper Bound: 577440.0
# Lower Bound: 577440.0

# %%
#Identify how many outliers are there in the ConvertedComp column.
(df['ConvertedComp']<lower) | (df['ConvertedComp']>upper)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 11547    False
# 11548    False
# 11549    False
# 11550    False
# 11551    False
# Name: ConvertedComp, Length: 11552, dtype: bool

# %%
#Create a new dataframe by removing the outliers from the ConvertedComp column.
# your code goes here
df2 = df['ConvertedComp'].clip(upper, lower)
df2.describe()
# Out:
# count     11552.0
# mean     577440.0
# std           0.0
# min      577440.0
# 25%      577440.0
# 50%      577440.0
# 75%      577440.0
# max      577440.0
# Name: ConvertedComp, dtype: float64

# %%
df['ConvertedComp'].median()
# Out:
# 577440.0
