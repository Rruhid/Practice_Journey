# %%
#CHAPTER 1  
import pandas as pd  
import numpy as np 
#import plotly as plt 
import matplotlib.pyplot as plt

text = 'data_practice/Canadaa.xlsx'
df_can = pd.read_excel(
    text,
    sheet_name = 'Sheet1',
    skiprows = range(20),
    skipfooter = 2)
print('Data is uploaded!')
# Out:
# Data is uploaded!

# %%
df_can.head()
#df_can.drop(['AREA', 'REG', 'DEV', 'Type', 'Coverage'], axis=1, inplace=True)
df_can.rename(columns = {'OdName':'Country', 'AreaName':'Continent','RegName':'Region'}, inplace=True)

# %%
df_can.head()
# Out:
#          Type    Coverage         Country  AREA Continent   REG  \
# 0  Immigrants  Foreigners     Afghanistan   935      Asia  5501
# 1  Immigrants  Foreigners         Albania   908    Europe   925
# 2  Immigrants  Foreigners         Algeria   903    Africa   912
# 3  Immigrants  Foreigners  American Samoa   909   Oceania   957
# 4  Immigrants  Foreigners         Andorra   908    Europe   925
#
#             Region  DEV             DevName  1980  ...  2004  2005  2006  \
# 0    Southern Asia  902  Developing regions    16  ...  2978  3436  3009
# 1  Southern Europe  901   Developed regions     1  ...  1450  1223   856
# 2  Northern Africa  902  Developing regions    80  ...  3616  3626  4807
# 3        Polynesia  902  Developing regions     0  ...     0     0     1
# 4  Southern Europe  901   Developed regions     0  ...     0     0     1
#
#    2007  2008  2009  2010  2011  2012  2013
# 0  2652  2111  1746  1758  2203  2635  2004
# 1   702   560   716   561   539   620   603
# ...

# %%
df_can.columns
# Out:
# Index([     'Type',  'Coverage',   'Country',      'AREA', 'Continent',
#              'REG',    'Region',       'DEV',   'DevName',        1980,
#               1981,        1982,        1983,        1984,        1985,
#               1986,        1987,        1988,        1989,        1990,
#               1991,        1992,        1993,        1994,        1995,
#               1996,        1997,        1998,        1999,        2000,
#               2001,        2002,        2003,        2004,        2005,
#               2006,        2007,        2008,        2009,        2010,
#               2011,        2012,        2013],
#       dtype='object')

# %%
df_can.columns = list(map(str, df_can.columns))

df_can.set_index('Country', inplace = True)
df_can
# Out:
#                       Type    Coverage  AREA Continent   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501
# Albania         Immigrants  Foreigners   908    Europe   925
# Algeria         Immigrants  Foreigners   903    Africa   912
# American Samoa  Immigrants  Foreigners   909   Oceania   957
# Andorra         Immigrants  Foreigners   908    Europe   925
# ...                    ...         ...   ...       ...   ...
# Viet Nam        Immigrants  Foreigners   935      Asia   920
# Western Sahara  Immigrants  Foreigners   903    Africa   912
# Yemen           Immigrants  Foreigners   935      Asia   922
# Zambia          Immigrants  Foreigners   903    Africa   910
# Zimbabwe        Immigrants  Foreigners   903    Africa   910
#
#                             Region  DEV             DevName  1980  1981  ...  \
# Country                                                                  ...
# ...

# %%
df_can['Total'] = df_can.sum(axis = 1)
df_can
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_7348\3324049657.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_can['Total'] = df_can.sum(axis = 1)
#                       Type    Coverage  AREA Continent   REG  \
# Country
# Afghanistan     Immigrants  Foreigners   935      Asia  5501
# Albania         Immigrants  Foreigners   908    Europe   925
# Algeria         Immigrants  Foreigners   903    Africa   912
# American Samoa  Immigrants  Foreigners   909   Oceania   957
# Andorra         Immigrants  Foreigners   908    Europe   925
# ...                    ...         ...   ...       ...   ...
# Viet Nam        Immigrants  Foreigners   935      Asia   920
# Western Sahara  Immigrants  Foreigners   903    Africa   912
# Yemen           Immigrants  Foreigners   935      Asia   922
# ...

# %%
years= list(map(str, range(1980, 2014)))
years
#df_can.loc['Yemen']
# Out:
# ['1980',
#  '1981',
#  '1982',
#  '1983',
#  '1984',
#  '1985',
#  '1986',
#  '1987',
#  '1988',
#  '1989',
#  '1990',
#  '1991',
#  '1992',
#  '1993',
#  '1994',
#  '1995',
#  '1996',
#  '1997',
#  '1998',
#  '1999',
#  '2000',
#  '2001',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013']

# %%
df_can[df_can.index == 'Japan']
df_can[df_can.index == 'China']
# Compare the distribution of the number of new immigrants from India and China for the period 1980 - 2013.
df_CI= df_can.loc[['China', 'India'], years].transpose()
#df_CI.plot()
df_CI.plot(kind='box', figsize=(10, 7), color ='blue') #can use: vert = False
plt.title('Box plots of Immigrants from China and India (1980 - 2013)')
plt.ylabel('Number of Immigrants')
plt.xlabel('Countries')
# Out:
# Text(0.5, 0, 'Countries')

# %%
fig = plt.figure()


ax0 = fig.add_subplot(1, 2, 1) # add subplot 1 (1 row, 2 columns, first plot)
ax1 = fig.add_subplot(1, 2, 2) # add subplot 2 (1 row, 2 columns, second plot).

df_CI.plot(kind='box', color = 'blue', vert=False, figsize = (20, 6), ax = ax0)
ax0.set_title('Box Plots of Immigrants from China and India (1980 - 2013)')
ax0.set_xlabel('Number of Immigrants')
ax0.set_ylabel('Countries')

# Subplot 2: Line plot
df_CI.plot(kind='line', figsize=(20, 6), ax=ax1) # add to subplot 2
ax1.set_title ('Line Plots of Immigrants from China and India (1980 - 2013)')
ax1.set_ylabel('Number of Immigrants')
ax1.set_xlabel('Years')
# Out:
# Text(0.5, 0, 'Years')

# %%
#Scatter Plots 
#Using a scatter plot, let's visualize the trend of total immigrantion to Canada (all countries combined) for the years 1980 - 2013.
# Since we are expecting to use the relationship betewen years and total population, we will convert years to int type.

# we can use the sum() method to get the total population per year
df_tot = pd.DataFrame(df_can[years].sum(axis=0))
#df_tot
# change the years to type int
df_tot.index = map(int, df_tot.index)
df_tot.reset_index(inplace = True)
#df_tot.columns

#df_tot.rename(columns={'index':'year','0':'total'}) #not worked for O

df_tot.columns = ['year', 'total']
df_tot

df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color = 'darkblue' )
plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

plt.show()

# %%
#Step 2: Plot the regression line on the scatter plot. 


x = df_tot['year']      # year on x-axis
y = df_tot['total']     # total on y-axis
fit = np.polyfit(x, y, deg=1)

fit

df_tot.plot(kind='scatter', x='year', y='total', figsize=(10, 6), color='darkblue')

plt.title('Total Immigration to Canada from 1980 - 2013')
plt.xlabel('Year')
plt.ylabel('Number of Immigrants')

# plot line of best fit
plt.plot(x, fit[0] * x + fit[1], color='red') # recall that x is the Years
plt.annotate('y={0:.0f} x + {1:.0f}'.format(fit[0], fit[1]), xy=(2000, 150000))

plt.show()

# print out the line of best fit
'No. Immigrants = {0:.0f} * Year + {1:.0f}'.format(fit[0], fit[1])
# Out:
# 'No. Immigrants = 5567 * Year + -10926195'

# %%
#Bubble Plots 
# Get the data for Brazil and Argentina. Like in the previous example, we will convert the Years to type int and include it in the dataframe.
 
# transposed dataframe
df_can_t = df_can[years].transpose()

# cast the Years (the index) to type int
df_can_t.index = map(int, df_can_t.index)

# let's label the index. This will automatically be the column name when we reset the index
df_can_t.index.name = 'Year'

# reset index to bring the Year in as a column
df_can_t.reset_index(inplace=True)

# view the changes
df_can_t.head()

# normalize Brazil data
norm_brazil = (df_can_t['Brazil'] - df_can_t['Brazil'].min()) / (df_can_t['Brazil'].max() - df_can_t['Brazil'].min())

# normalize Argentina data
norm_argentina = (df_can_t['Argentina'] - df_can_t['Argentina'].min()) / (df_can_t['Argentina'].max() - df_can_t['Argentina'].min()) 

# Brazil
ax0 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Brazil',
                    figsize=(14, 8),
                    alpha=0.5,  # transparency
                    color='green',
                    s=norm_brazil * 2000 + 10,  # pass in weights 
                    xlim=(1975, 2015)
                    )

# Argentina
ax1 = df_can_t.plot(kind='scatter',
                    x='Year',
                    y='Argentina',
                    alpha=0.5,
                    color="blue",
                    s=norm_argentina * 2000 + 10,
                    ax=ax0
                    )

ax0.set_ylabel('Number of Immigrants')
ax0.set_title('Immigration from Brazil and Argentina from 1980 to 2013')
ax0.legend(['Brazil', 'Argentina'], loc='upper left', fontsize='x-large')

# %%
#import matplotlib  
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.style.use('ggplot') # optional: for ggplot-like style

# check for latest version of Matplotlib
print('Matplotlib version: ', mpl.__version__) # >= 2.0.0
# Out:
# Matplotlib version:  3.5.3

# %%
df_can.head()
df_continents = df_can.groupby('Continent', axis=0).sum()
df_continents
# Out:
#                                   AREA     REG    DEV   1980   1981   1982  \
# Continent
# Africa                           48762   49242  48708   3951   4363   3819
# Asia                             45815  109147  44197  31025  34314  30214
# Europe                           39044   39754  38743  39760  44802  42720
# Latin America and the Caribbean  29832   30395  29766  13081  15215  16769
# Northern America                  1810    1810   1802   9378  10030   9074
# Oceania                          12726   13210  12626   1942   1839   1675
#
#                                   1983   1984   1985   1986  ...    2005  \
# Continent                                                    ...
# Africa                            2671   2639   2650   3782  ...   27523
# Asia                             24696  27274  23850  28739  ...  159253
# Europe                           24638  22287  20844  24370  ...   35955
# ...

# %%
 
df_continents['Total']
df_continents['Total'].plot(kind = 'pie', figsize = (8,9), autopct = '%1.1f%%', 
                           startangle = 90, shadow = True)
plt.title('Immigration to Canada by Continent [1980 - 2013]')
# Out:
# Text(0.5, 1.0, 'Immigration to Canada by Continent [1980 - 2013]')

# %%
#Let's make a chart another way 
colors_list = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue', 'lightgreen', 'pink'] 
explode_list = [0.1, 0, 0, 0, 0.1, 0.1] # ratio for each continent with which to offset each wedge.

df_continents['Total'].plot(kind='pie',
                            figsize=(15, 6),
                            autopct='%1.1f%%', 
                            startangle=90,    
                            shadow=True,       
                            labels=None,         # turn off labels on pie chart
                            pctdistance=1.12,    # the ratio between the center of each pie slice and the start of the text generated by autopct 
                            colors=colors_list,  # add custom colors
                            explode=explode_list # 'explode' lowest 3 continents
                            )

# scale the title up by 12% to match pctdistance
plt.title('Immigration to Canada by Continent [1980 - 2013]', y=1.12) 

plt.axis('equal') 

# add legend
plt.legend(labels=df_continents.index, loc='upper left') 

plt.show()

# %%
#CHAPTER 2
import pandas as pd 
import numpy as np 
path = "data_practice/auto.csv"
df = pd.read_csv(path, header=None)


headers = ["symboling","normalized-losses","make","fuel-type","aspiration", "num-of-doors","body-style",
         "drive-wheels","engine-location","wheel-base", "length","width","height","curb-weight","engine-type",
         "num-of-cylinders", "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower",
         "peak-rpm","city-mpg","highway-mpg","price"]
df.columns = headers

#i = df.select_dtypes(exclude=['number']).apply(lambda x: x.str.contains('\?')) 
#c = np.sum(i.values)
#c
df.replace("?", np.nan, inplace = True)

df['horsepower'] = df['horsepower'].astype('float', copy = True)
df
df.isnull().sum()
#df.dtypes
df['horsepower'].value_counts()


#df.head(5)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot

plt.pyplot.hist(df["horsepower"])

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")

#or with the help of plot()
#df['horsepower'].plot(kind='hist', figsize=(8, 5))
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
#Splitting it to categories 

bins = np.linspace(min(df['horsepower']), max(df['horsepower']),4)
#print(bins)
group_names = ['Low', 'Medium', 'High']
df['horsepower-binned'] = pd.cut(df['horsepower'], bins, labels=group_names, include_lowest=True) 
df[['horsepower','horsepower-binned']].head(20)

pyplot.bar(group_names, df['horsepower-binned'].value_counts(), color='g')
plt.pyplot.xlabel('horsepower')
plt.pyplot.ylabel('count')
plt.pyplot.title('Horsepower bins')
# Out:
# Text(0.5, 1.0, 'Horsepower bins')

# %%
#df.columns 
#df['fuel-type'].tail(20)
#dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.tail(20)
dummy_variable_1.rename(columns = {'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True)
dummy_variable_1.columns

#drop original column "fuel-type" from "df" 
#df.drop('fuel-type', axis = 1, inplace = True)

df = pd.concat([df, dummy_variable_1], axis = 1)
df.head()
#df.to_csv('clean_df.csv')
# Out:
#    symboling normalized-losses         make aspiration num-of-doors  \
# 0          3               NaN  alfa-romero        std          two
# 1          3               NaN  alfa-romero        std          two
# 2          1               NaN  alfa-romero        std          two
# 3          2               164         audi        std         four
# 4          2               164         audi        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  ...  \
# 0  convertible          rwd           front        88.6   168.8  ...
# 1  convertible          rwd           front        88.6   168.8  ...
# 2    hatchback          rwd           front        94.5   171.2  ...
# 3        sedan          fwd           front        99.8   176.6  ...
# 4        sedan          4wd           front        99.4   176.6  ...
#
#    horsepower  peak-rpm  city-mpg highway-mpg  price  horsepower-binned  \
# ...

# %%
#CHAPTER 3  
import csv, sqlite3 
con = sqlite3.connect('Test.db')
# %load_ext sql 
# %sql sqlite:///Test.db

# %%
# %%sql
# CREATE TABLE INTERNATIONAL_STUDENT_TEST_SCORES (
# 	country VARCHAR(50),
# 	first_name VARCHAR(50),
# 	last_name VARCHAR(50),
# 	test_score INT
# );
# Out:
#    sqlite:///Exercises.db
#  * sqlite:///Test.db
# Done.
# []

# %%
# %%sql
#
# INSERT INTO "INTERNATIONAL_STUDENT_TEST_SCORES" (country, first_name, last_name, test_score) VALUES
# ('Ghana', 'Celinda', 'Malkin', 11),
# ('Ukraine', 'Guillermo', 'Furze', 12),
# ('Greece', 'Aharon', 'Tunnow', 14),
# ('Russia', 'Bail', 'Goodwin', 13),
# ('Poland', 'Cole', 'Winteringham', 49),
# ('Sweden', 'Emlyn', 'Erricker', 55),
# ('Russia', 'Cathee', 'Sivewright', 49),
# ('China', 'Barny', 'Ingerson', 57),
# ('Uganda', 'Sharla', 'Papaccio', 55),
# ('China', 'Stella', 'Youens', 51),
# ('Poland', 'Julio', 'Buesden', 48),
# ('United States', 'Tiffie', 'Cosely', 58),
# ('Poland', 'Auroora', 'Stiffell', 45),
# ('China', 'Clarita', 'Huet', 52),
# ('Poland', 'Shannon', 'Goulden', 45),
# ('Philippines', 'Emylee', 'Privost', 50),
# ('France', 'Madelina', 'Burk', 49),
# ('China', 'Saunderson', 'Root', 58),
# ('Indonesia', 'Bo', 'Waring', 55),
# ('China', 'Hollis', 'Domotor', 45),
# ('Russia', 'Robbie', 'Collip', 46),
# ('Philippines', 'Davon', 'Donisi', 46),
# ('China', 'Cristabel', 'Radeliffe', 48),
# ('China', 'Wallis', 'Bartleet', 58),
# ('Moldova', 'Arleen', 'Stailey', 38),
# ('Ireland', 'Mendel', 'Grumble', 58),
# ('China', 'Sallyann', 'Exley', 51),
# ('Mexico', 'Kain', 'Swaite', 46),
# ('Indonesia', 'Alonso', 'Bulteel', 45),
# ('Armenia', 'Anatol', 'Tankus', 51),
# ('Indonesia', 'Coralyn', 'Dawkins', 48),
# ('China', 'Deanne', 'Edwinson', 45),
# ('China', 'Georgiana', 'Epple', 51),
# ('Portugal', 'Bartlet', 'Breese', 56),
# ('Azerbaijan', 'Idalina', 'Lukash', 50),
# ('France', 'Livvie', 'Flory', 54),
# ('Malaysia', 'Nonie', 'Borit', 48),
# ('Indonesia', 'Clio', 'Mugg', 47),
# ('Brazil', 'Westley', 'Measor', 48),
# ('Philippines', 'Katrinka', 'Sibbert', 51),
# ('Poland', 'Valentia', 'Mounch', 50),
# ('Norway', 'Sheilah', 'Hedditch', 53),
# ('Papua New Guinea', 'Itch', 'Jubb', 50),
# ('Latvia', 'Stesha', 'Garnson', 53),
# ('Canada', 'Cristionna', 'Wadmore', 46),
# ('China', 'Lianna', 'Gatward', 43),
# ('Guatemala', 'Tanney', 'Vials', 48),
# ('France', 'Alma', 'Zavittieri', 44),
# ('China', 'Alvira', 'Tamas', 50),
# ('United States', 'Shanon', 'Peres', 45),
# ('Sweden', 'Maisey', 'Lynas', 53),
# ('Indonesia', 'Kip', 'Hothersall', 46),
# ('China', 'Cash', 'Landis', 48),
# ('Panama', 'Kennith', 'Digance', 45),
# ('China', 'Ulberto', 'Riggeard', 48),
# ('Switzerland', 'Judy', 'Gilligan', 49),
# ('Philippines', 'Tod', 'Trevaskus', 52),
# ('Brazil', 'Herold', 'Heggs', 44),
# ('Latvia', 'Verney', 'Note', 50),
# ('Poland', 'Temp', 'Ribey', 50),
# ('China', 'Conroy', 'Egdal', 48),
# ('Japan', 'Gabie', 'Alessandone', 47),
# ('Ukraine', 'Devlen', 'Chaperlin', 54),
# ('France', 'Babbette', 'Turner', 51),
# ('Czech Republic', 'Virgil', 'Scotney', 52),
# ('Tajikistan', 'Zorina', 'Bedow', 49),
# ('China', 'Aidan', 'Rudeyeard', 50),
# ('Ireland', 'Saunder', 'MacLice', 48),
# ('France', 'Waly', 'Brunstan', 53),
# ('China', 'Gisele', 'Enns', 52),
# ('Peru', 'Mina', 'Winchester', 48),
# ('Japan', 'Torie', 'MacShirrie', 50),
# ('Russia', 'Benjamen', 'Kenford', 51),
# ('China', 'Etan', 'Burn', 9),
# ('Russia', 'Merralee', 'Chaperlin', 38),
# ('Indonesia', 'Lanny', 'Malam', 49),
# ('Canada', 'Wilhelm', 'Deeprose', 54),
# ('Czech Republic', 'Lari', 'Hillhouse', 48),
# ('China', 'Ossie', 'Woodley', 52),
# ('Macedonia', 'April', 'Tyer', 50),
# ('Vietnam', 'Madelon', 'Dansey', 53),
# ('Ukraine', 'Korella', 'McNamee', 52),
# ('Jamaica', 'Linnea', 'Cannam', 43),
# ('China', 'Mart', 'Coling', 52),
# ('Indonesia', 'Marna', 'Causbey', 47),
# ('China', 'Berni', 'Daintier', 55),
# ('Poland', 'Cynthia', 'Hassell', 49),
# ('Canada', 'Carma', 'Schule', 49),
# ('Indonesia', 'Malia', 'Blight', 48),
# ('China', 'Paulo', 'Seivertsen', 47),
# ('Niger', 'Kaylee', 'Hearley', 54),
# ('Japan', 'Maure', 'Jandak', 46),
# ('Argentina', 'Foss', 'Feavers', 45),
# ('Venezuela', 'Ron', 'Leggitt', 60),
# ('Russia', 'Flint', 'Gokes', 40),
# ('China', 'Linet', 'Conelly', 52),
# ('Philippines', 'Nikolas', 'Birtwell', 57),
# ('Australia', 'Eduard', 'Leipelt', 53)
# Out:
#  * sqlite:///Test.db
# 98 rows affected.
# []

# %%
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES
# Out:
#    sqlite:///Exercises.db
#  * sqlite:///Test.db
# Done.
# [('Ghana', 'Celinda', 'Malkin', 51),
#  ('Ukraine', 'Guillermo', 'Furze', 53),
#  ('Greece', 'Aharon', 'Tunnow', 48),
#  ('Russia', 'Bail', 'Goodwin', 46),
#  ('Poland', 'Cole', 'Winteringham', 49),
#  ('Sweden', 'Emlyn', 'Erricker', 55),
#  ('Russia', 'Cathee', 'Sivewright', 49),
#  ('China', 'Barny', 'Ingerson', 57),
#  ('Uganda', 'Sharla', 'Papaccio', 55),
#  ('China', 'Stella', 'Youens', 51),
#  ('Poland', 'Julio', 'Buesden', 48),
#  ('United States', 'Tiffie', 'Cosely', 58),
#  ('Poland', 'Auroora', 'Stiffell', 45),
#  ('China', 'Clarita', 'Huet', 52),
#  ('Poland', 'Shannon', 'Goulden', 45),
#  ('Philippines', 'Emylee', 'Privost', 50),
#  ('France', 'Madelina', 'Burk', 49),
#  ('China', 'Saunderson', 'Root', 58),
#  ('Indonesia', 'Bo', 'Waring', 55),
#  ('China', 'Hollis', 'Domotor', 45),
#  ('Russia', 'Robbie', 'Collip', 46),
#  ('Philippines', 'Davon', 'Donisi', 46),
#  ('China', 'Cristabel', 'Radeliffe', 48),
# ...

# %%
 # %sql select first_name, COUNT(*) as Total from  INTERNATIONAL_STUDENT_TEST_SCORES WHERE test_score > 10.0 GROUP BY test_score;
# Out:
#  * sqlite:///Test.db
# Done.
# [('Arleen', 4),
#  ('Flint', 2),
#  ('Lianna', 4),
#  ('Alma', 4),
#  ('Auroora', 16),
#  ('Bail', 14),
#  ('Clio', 8),
#  ('Aharon', 28),
#  ('Cole', 16),
#  ('Emylee', 20),
#  ('Celinda', 16),
#  ('Clarita', 16),
#  ('Guillermo', 16),
#  ('Livvie', 8),
#  ('Emlyn', 8),
#  ('Bartlet', 2),
#  ('Barny', 4),
#  ('Tiffie', 8),
#  ('Ron', 2)]

# %%
country = "Canada"
# %sql select * from INTERNATIONAL_STUDENT_TEST_SCORES where country= :country
# Out:
#    sqlite:///Exercises.db
#  * sqlite:///Test.db
# Done.
# [('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49),
#  ('Canada', 'Cristionna', 'Wadmore', 46),
#  ('Canada', 'Wilhelm', 'Deeprose', 54),
#  ('Canada', 'Carma', 'Schule', 49)]

# %%
test_score_distribution = %sql select country as State, test_score as Test_Score, count(*) as Frequency from INTERNATIONAL_STUDENT_TEST_SCORES GROUP BY test_score  ORDER BY Frequency DESC; 
test_score_distribution
# Out:
#  * sqlite:///Test.db
# Done.
# [('Greece', 48, 28),
#  ('Philippines', 50, 20),
#  ('Ukraine', 53, 16),
#  ('China', 52, 16),
#  ('Ghana', 51, 16),
#  ('Poland', 49, 16),
#  ('Poland', 45, 16),
#  ('Russia', 46, 14),
#  ('United States', 58, 8),
#  ('Sweden', 55, 8),
#  ('France', 54, 8),
#  ('Indonesia', 47, 8),
#  ('China', 57, 4),
#  ('France', 44, 4),
#  ('China', 43, 4),
#  ('Moldova', 38, 4),
#  ('Venezuela', 60, 2),
#  ('Portugal', 56, 2),
#  ('Russia', 40, 2)]

# %%
dataframe = test_score_distribution.DataFrame()
import seaborn  

seaborn.barplot(x='Test_Score', y ='Frequency', data = dataframe)
# Out:
# <AxesSubplot: xlabel='Test_Score', ylabel='Frequency'>

# %%
# %sql select avg(test_score) as test_score from INTERNATIONAL_STUDENT_TEST_SCORES
# Out:
#  * sqlite:///Test.db
# Done.
# [(49.69387755102041,)]

# %%
# %sql SELECT name FROM sqlite_master WHERE type='table'
# Out:
#  * sqlite:///Test.db
# Done.
# [('INTERNATIONAL_STUDENT_TEST_SCORES',), ('chicago_crime_data',)]

# %%
# %sql SELECT count(*) FROM chicago_crime_data;
# Out:
#  * sqlite:///Test.db
# Done.
# [(533,)]

# %%
# %sql select ID, count(*) from  CHICAGO_CRIME_DATA where CASE_NUMBER = 'G652158'
# Out:
#  * sqlite:///Test.db
# Done.
# [(1819413, 1)]

# %%
# %sql select MAX(IUCR) AS MAX_IUCR from  CHICAGO_CRIME_DATA
# Out:
#  * sqlite:///Test.db
# Done.
# [('9901',)]

# %%
# %sql select DESCRIPTION AS DESC from  CHICAGO_CRIME_DATA WHERE IUCR = 9901
# Out:
#  * sqlite:///Test.db
# Done.
# [('DOMESTIC VIOLENCE',)]

# %%
# %sql select  ID, DESCRIPTION  FROM CHICAGO_CRIME_DATA ORDER BY IUCR DESC nulls last limit 10
# Out:
#  * sqlite:///Test.db
# Done.
# [(1326195, 'DOMESTIC VIOLENCE'),
#  (3969617, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (3072896, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (2859254, 'THEFT/RECOVERY: AUTOMOBILE'),
#  (9651438, 'ATT: AUTOMOBILE'),
#  (2316019, 'TRUCK, BUS, MOTOR HOME'),
#  (10268156, 'AUTOMOBILE'),
#  (6672913, 'AUTOMOBILE'),
#  (5835389, 'AUTOMOBILE'),
#  (7427845, 'AUTOMOBILE')]

# %%
# %sql select case_number,primary_type, description from chicago_crime_data where primary_type = 'offense involving children' or description like '%minor%'
# Out:
#  * sqlite:///Test.db
# Done.
# [('HL266884', 'LIQUOR LAW VIOLATION', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'LIQUOR LAW VIOLATION', 'ILLEGAL CONSUMPTION BY MINOR')]

# %%
# %sql select case_number, primary_type from chicago_crime_data where primary_type='KIDNAPPING'
# Out:
#  * sqlite:///Test.db
# Done.
# [('HN144152', 'KIDNAPPING')]

# %%
# %sql select primary_type as crime_recorded_at_school,\
LOCATION_DESCRIPTION as location from  chicago_crime_data where location_description like '%SCHOOL%'
# Out:
#  * sqlite:///Test.db
# Done.
# [('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL DAMAGE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'SCHOOL, PUBLIC, BUILDING')]

# %%
# %sql select * from chicago_crime_data
# Out:
#  * sqlite:///Test.db
# Done.
# [(3512276, 'HK587712', '2004-08-28', '047XX S KEDZIE AVE', '890', 'THEFT', 'FROM BUILDING', 'SMALL RETAIL STORE', 0, 0, 911, 9, 14.0, 58.0, '6', 1155838.0, 1873050.0, 2004, 41.8074405, -87.70395585, '(41.8074405, -87.703955849)'),
#  (3406613, 'HK456306', '2004-06-26', '009XX N CENTRAL PARK AVE', '820', 'THEFT', '$500 AND UNDER', 'OTHER', 0, 0, 1112, 11, 27.0, 23.0, '6', 1152206.0, 1906127.0, 2004, 41.89827996, -87.71640551, '(41.898279962, -87.716405505)'),
#  (8002131, 'HT233595', '2011-04-04', '043XX S WABASH AVE', '820', 'THEFT', '$500 AND UNDER', 'NURSING HOME/RETIREMENT HOME', 0, 0, 221, 2, 3.0, 38.0, '6', 1177436.0, 1876313.0, 2011, 41.81593313, -87.62464213, '(41.815933131, -87.624642127)'),
#  (7903289, 'HT133522', '2010-12-30', '083XX S KINGSTON AVE', '840', 'THEFT', 'FINANCIAL ID THEFT: OVER $300', 'RESIDENCE', 0, 0, 423, 4, 7.0, 46.0, '6', 1194622.0, 1850125.0, 2010, 41.74366532, -87.56246276, '(41.743665322, -87.562462756)'),
# ...

# %%
# %sql select CD.LOCATION_DESCRIPTION, CD.ARREST, IST.country from CHICAGO_CRIME_DATA as CD\
INNER JOIN INTERNATIONAL_STUDENT_TEST_SCORES as IST on CD.DISTRICT= IST.Test_Score where CD.LOCATION_DESCRIPTION = 'STREET';
# Out:
#  * sqlite:///Test.db
# Done.
# [('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ghana'),
#  ('STREET', 0, 'Ghana'),
#  ('STREET', 0, 'Ghana'),
#  ('STREET', 0, 'Ghana'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 1, 'China'),
#  ('STREET', 0, 'China'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 0, 'China'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Ukraine'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 0, 'Greece'),
#  ('STREET', 1, 'China'),
#  ('STREET', 1, 'Ghana'),
#  ('STREET', 1, 'Ghana'),
#  ('STREET', 1, 'China'),
#  ('STREET', 1, 'Ukraine'),
#  ('STREET', 1, 'Ukraine'),
#  ('STREET', 1, 'Ukraine'),
#  ('STREET', 1, 'Ukraine'),
#  ('STREET', 1, 'Ghana'),
# ...

# %%
# %sql select community_area_number, count(case_number) as no_of_cases from CHICAGO_CRIME_DATA\
group by community_area_number order by no_of_cases desc limit 10;
# Out:
#  * sqlite:///Test.db
# Done.
# [(25.0, 43),
#  (None, 43),
#  (23.0, 22),
#  (68.0, 21),
#  (29.0, 16),
#  (28.0, 16),
#  (8.0, 15),
#  (71.0, 14),
#  (24.0, 13),
#  (67.0, 12)]

# %%
# %sql select CD.case_number, CD.primary_type, IST.country from CHICAGO_CRIME_DATA as CD\
INNER JOIN INTERNATIONAL_STUDENT_TEST_SCORES as IST on CD.DISTRICT= IST.Test_Score;
# Out:
#  * sqlite:///Test.db
# Done.
# [('HK587712', 'THEFT', 'China'),
#  ('HK456306', 'THEFT', 'Ghana'),
#  ('HK456306', 'THEFT', 'Ghana'),
#  ('HS540106', 'THEFT', 'Ukraine'),
#  ('HS540106', 'THEFT', 'Ukraine'),
#  ('HT180228', 'THEFT', 'Ukraine'),
#  ('HT180228', 'THEFT', 'Ukraine'),
#  ('HK108680', 'THEFT', 'Ghana'),
#  ('HK108680', 'THEFT', 'Ghana'),
#  ('HY396729', 'THEFT', 'Greece'),
#  ('HY396729', 'THEFT', 'Greece'),
#  ('JB151690', 'THEFT', 'China'),
#  ('G256545', 'THEFT', 'China'),
#  ('HH201585', 'THEFT', 'Greece'),
#  ('HH201585', 'THEFT', 'Greece'),
#  ('G212935', 'THEFT', 'Ukraine'),
#  ('G212935', 'THEFT', 'Ukraine'),
#  ('HL590300', 'THEFT', 'Ukraine'),
#  ('HL590300', 'THEFT', 'Ukraine'),
#  ('HL680775', 'THEFT', 'Greece'),
#  ('HL680775', 'THEFT', 'Greece'),
#  ('HY377901', 'THEFT', 'Greece'),
#  ('HY377901', 'THEFT', 'Greece'),
#  ('JA412895', 'THEFT', 'Ghana'),
#  ('JA412895', 'THEFT', 'Ghana'),
#  ('HJ652747', 'THEFT', 'Ukraine'),
# ...

# %%
# %sql select CD.case_number, CD.primary_type, IST.country from CHICAGO_CRIME_DATA as CD\
LEFT JOIN INTERNATIONAL_STUDENT_TEST_SCORES as IST on CD.DISTRICT= IST.Test_Score ORDER BY CASE_NUMBER DESC;
# Out:
#  * sqlite:///Test.db
# Done.
# [('JB213238', 'BATTERY', None),
#  ('JB155558', 'OBSCENITY', None),
#  ('JB151690', 'THEFT', 'China'),
#  ('JA560123', 'CRIMINAL DAMAGE', None),
#  ('JA559176', 'THEFT', None),
#  ('JA557966', 'ROBBERY', 'Ukraine'),
#  ('JA557966', 'ROBBERY', 'Ukraine'),
#  ('JA550741', 'DECEPTIVE PRACTICE', None),
#  ('JA503725', 'THEFT', None),
#  ('JA496716', 'BATTERY', 'Ukraine'),
#  ('JA496716', 'BATTERY', 'Ukraine'),
#  ('JA490957', 'BATTERY', None),
#  ('JA483294', 'CRIMINAL DAMAGE', None),
#  ('JA470839', 'OTHER OFFENSE', None),
#  ('JA462321', 'ASSAULT', None),
#  ('JA460432', 'BATTERY', None),
#  ('JA455629', 'CRIMINAL TRESPASS', None),
#  ('JA412895', 'THEFT', 'Ghana'),
#  ('JA412895', 'THEFT', 'Ghana'),
#  ('JA394755', 'DECEPTIVE PRACTICE', 'Greece'),
#  ('JA394755', 'DECEPTIVE PRACTICE', 'Greece'),
#  ('JA393243', 'CRIMINAL TRESPASS', None),
#  ('JA384163', 'THEFT', 'Greece'),
#  ('JA384163', 'THEFT', 'Greece'),
#  ('JA359626', 'HOMICIDE', None),
# ...
