# %% [markdown]
# # We analyze the syntax and query principles  of SQL queries, as well as popular examples  with a database(MySQL). To better understand the query and show its result, I connected a Jupyter notebook to a MySQL database.
#
# # Разбираем принципы работы, структуру SQL-запросов, а также популярные примеры использования запросов SQL с БД. Чтобы лучше понять команды и отобразить результат, я подключил Jupiter notepad к базе данных MySQL.

# %%
import mysql.connector
# %load_ext sql
# %sql mysql+mysqldb://root:qwe123@127.0.0.1:3306/sql_advanced

# %% [markdown]
# # *Note: The "LIMIT" command is used intentionally to avoid large data output.
#
# # *Примечание. Команда "LIMIT" используется намеренно, чтобы избежать вывода больших объемов данных.

# %% [markdown]
# # Select address and city_id from the table
#
# # Возврашение столбцов адрес и идентификатор города

# %%
# %sql SELECT address, city_id  FROM address LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('47 MySakila Drive', 300),
#  ('28 MySQL Boulevard', 576),
#  ('23 Workhaven Lane', 300),
#  ('1411 Lillydale Drive', 576),
#  ('1913 Hanoi Way', 463)]

# %% [markdown]
# # Lets Print out the list of all customers
#
# # Отобразим список всех клиентов

# %%
# %sql SELECT first_name,last_name, email from customer LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org'),
#  ('PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org'),
#  ('LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org'),
#  ('BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org'),
#  ('ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org')]

# %% [markdown]
# # The list of all customers by customer_id ascending, amount descending order
#
# #  Список всех клиентов по возрастающей customer_id  и убывающей цены

# %%
# %sql SELECT * FROM payment ORDER BY customer_id, amount DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (14, 1, 1, 6163, Decimal('7.99'), datetime.datetime(2005, 7, 11, 10, 13, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (10, 1, 2, 4526, Decimal('5.99'), datetime.datetime(2005, 7, 8, 3, 17, 5), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (11, 1, 1, 4611, Decimal('5.99'), datetime.datetime(2005, 7, 8, 7, 33, 56), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %% [markdown]
# # Список  всех уникальных категорий фильма cо сроком аренды
#
# # List of distint film categories with rental period

# %%
# %sql SELECT DISTINCT rating, rental_duration FROM film
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 25 rows affected.
# [('PG', 6),
#  ('G', 3),
#  ('NC-17', 7),
#  ('G', 5),
#  ('G', 6),
#  ('PG', 3),
#  ('PG-13', 6),
#  ('R', 6),
#  ('PG-13', 3),
#  ('NC-17', 6),
#  ('PG', 4),
#  ('NC-17', 5),
#  ('R', 3),
#  ('R', 4),
#  ('PG-13', 5),
#  ('PG-13', 4),
#  ('PG-13', 7),
#  ('R', 5),
#  ('NC-17', 4),
#  ('PG', 7),
#  ('G', 7),
#  ('G', 4),
#  ('PG', 5),
#  ('R', 7),
#  ('NC-17', 3)]

# %% [markdown]
# # A marketer member asks me to make different prices that have been paid
#
# # Сотрудник отдела маркетинга просит указать разные(уникальные) цены, которые были оплачены

# %%
# %sql SELECT DISTINCT amount from payment ORDER BY amount DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(Decimal('10.99'),),
#  (Decimal('9.99'),),
#  (Decimal('8.99'),),
#  (Decimal('7.99'),),
#  (Decimal('6.99'),)]

# %% [markdown]
# # Let's count how much these are
#
# # Давайте посчитаем их

# %%
#%sql SELECT COUNT(first_name) FROM customer 
#%sql SELECT COUNT(*) FROM customer 
# %sql SELECT COUNT(DISTINCT amount) as count FROM payment
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(11,)]

# %% [markdown]
# # Create a list of all the distinct distrcits customers are from
#
# # Создаем список всех клиентов из разных районов

# %%
 # %sql SELECT DISTINCT district FROM address
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 9 rows affected.
# [(' ',),
#  ('Esfahan',),
#  ('Yerevan',),
#  ('Moscow',),
#  ('California',),
#  ('Kalmykia',),
#  ('Nagasaki',),
#  ('Taipei',),
#  ('Piemonte',)]

# %% [markdown]
# # What is the latest rental date?
#
# # Выведим последнюю дату аренды?

# %%
# %sql SELECT * FROM payment ORDER BY payment_date DESC LIMIT 1
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(145, 5, 2, 13209, Decimal('0.99'), datetime.datetime(2006, 2, 14, 15, 16, 3), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %% [markdown]
# # How many films does the company have?
#
# # Сколько фильмов у компании?

# %%
 
# %sql SELECT COUNT(*) as Count_of_Films  FROM film
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(154,)]

# %% [markdown]
# # How many distinct lastnames of customers are there?
#
# # Сколько разных фамилий у клиентов?

# %%
# %sql SELECT COUNT(DISTINCT last_name) AS COUNT FROM customer
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(89,)]

# %% [markdown]
# # Кол. платежев с суммой 0.99
#
# # Number of paymments with 0.99

# %%
# %sql SELECT COUNT(*) AS Count FROM payment WHERE amount = 0.99
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(61,)]

# %% [markdown]
# # Кол. платежей между иден. (1000 и 4000)
#
# # Number of payments between (id. of 1000 and 4000)

# %%
#%sql SELECT * FROM payment WHERE rental_id>1000 AND rental_id < 4000
#OR 
# %sql SELECT * FROM payment WHERE rental_id BETWEEN 1000 AND 4000 ORDER BY 5 DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (1315, 48, 2, 1689, Decimal('9.99'), datetime.datetime(2005, 6, 16, 12, 18, 41), datetime.datetime(2006, 2, 15, 22, 12, 40)),
#  (62, 3, 1, 1546, Decimal('8.99'), datetime.datetime(2005, 6, 16, 1, 34, 5), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (451, 17, 1, 2684, Decimal('8.99'), datetime.datetime(2005, 6, 19, 12, 29, 8), datetime.datetime(2006, 2, 15, 22, 12, 32)),
#  (389, 15, 1, 3550, Decimal('7.99'), datetime.datetime(2005, 7, 6, 2, 29, 21), datetime.datetime(2006, 2, 15, 22, 12, 32))]

# %% [markdown]
# # Выведем все оплаты за исключением '2005-06-15'  и '2005-06-21 12:00'
#
# # Display all the payments except '2005-06-15' and '2005-06-21 12:00'

# %%
# %sql SELECT * FROM payment WHERE payment_date NOT BETWEEN '2005-06-15' AND '2005-06-21 12:00'\
ORDER BY payment_date DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(145, 5, 2, 13209, Decimal('0.99'), datetime.datetime(2006, 2, 14, 15, 16, 3), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (253, 9, 1, 15813, Decimal('4.99'), datetime.datetime(2006, 2, 14, 15, 16, 3), datetime.datetime(2006, 2, 15, 22, 12, 31)),
#  (59, 2, 2, 15907, Decimal('4.99'), datetime.datetime(2005, 8, 23, 17, 39, 35), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (230, 8, 1, 15805, Decimal('4.99'), datetime.datetime(2005, 8, 23, 14, 31, 19), datetime.datetime(2006, 2, 15, 22, 12, 31)),
#  (229, 8, 1, 15764, Decimal('2.99'), datetime.datetime(2005, 8, 23, 13, 5, 10), datetime.datetime(2006, 2, 15, 22, 12, 31))]

# %% [markdown]
# # Фильтруем цену и дату, давая дополнительное условие
#
# # Sort it based on the amount and date

# %%
# %sql SELECT  * FROM payment WHERE amount BETWEEN 2 AND 4 AND payment_date\
BETWEEN '2005-08-17' AND '2005-08-21' ORDER BY payment_date DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 15 rows affected.
# [(103, 4, 1, 13704, Decimal('2.99'), datetime.datetime(2005, 8, 20, 9, 32, 4), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (82, 3, 2, 13610, Decimal('2.99'), datetime.datetime(2005, 8, 20, 6, 14, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (204, 7, 1, 13476, Decimal('2.99'), datetime.datetime(2005, 8, 20, 1, 6, 4), datetime.datetime(2006, 2, 15, 22, 12, 31)),
#  (203, 7, 2, 13373, Decimal('2.99'), datetime.datetime(2005, 8, 19, 21, 23, 31), datetime.datetime(2006, 2, 15, 22, 12, 31)),
#  (28, 1, 2, 13176, Decimal('2.99'), datetime.datetime(2005, 8, 19, 13, 56, 54), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (55, 2, 1, 12963, Decimal('2.99'), datetime.datetime(2005, 8, 19, 6, 26, 4), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (138, 5, 1, 12797, Decimal('2.99'), datetime.datetime(2005, 8, 19, 0, 24, 8), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %% [markdown]
# # Фильтруем платежи где цена больше 5.
#
# # Print out the rows where amount is higher than 5

# %%
# %sql SELECT * FROM payment WHERE amount > 5 ORDER BY amount DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(44, 2, 2, 9236, Decimal('10.99'), datetime.datetime(2005, 7, 30, 13, 47, 43), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (69, 3, 2, 7503, Decimal('10.99'), datetime.datetime(2005, 7, 27, 20, 23, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (1315, 48, 2, 1689, Decimal('9.99'), datetime.datetime(2005, 6, 16, 12, 18, 41), datetime.datetime(2006, 2, 15, 22, 12, 40)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (224, 8, 1, 11232, Decimal('9.99'), datetime.datetime(2005, 8, 2, 13, 4, 12), datetime.datetime(2006, 2, 15, 22, 12, 31))]

# %% [markdown]
# # Let's print all the rows where address2 equals to NULL
#
# # Выведем все поля имеющие пустые значения в столбце address2

# %%
# %sql SELECT * FROM address WHERE  address2 is NULL LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(1, '47 MySakila Drive', None, ' ', 300, None, ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (2, '28 MySQL Boulevard', None, ' ', 576, None, ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (3, '23 Workhaven Lane', None, ' ', 300, None, ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (4, '1411 Lillydale Drive', None, ' ', 576, None, ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (5, '1913 Hanoi Way', None, ' ', 463, '35200', ' ', datetime.datetime(2006, 2, 15, 4, 45, 30))]

# %% [markdown]
# # Inventory mamager asks me how many rentals  have not returned yet
#
# # Менеджер спрашивает о кол. не вернувшиеся арендаторов

# %%
#Inventory mamager asks me how many rentals  have not returned yet  
# %sql SELECT COUNT(*) AS Count FROM rental WHERE return_date is NULL
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(6,)]

# %%
#Sales manager asks for a list of all payments id's with amount less or equal to 3. Include payment_id and amount  
# %sql SELECT payment_id,amount FROM payment WHERE amount <=3 ORDER BY amount DESC LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(1, Decimal('2.99')),
#  (41, Decimal('2.99')),
#  (34, Decimal('2.99')),
#  (48, Decimal('2.99')),
#  (15, Decimal('2.99')),
#  (35, Decimal('2.99')),
#  (31, Decimal('2.99')),
#  (20, Decimal('2.99')),
#  (21, Decimal('2.99')),
#  (266, Decimal('2.99'))]

# %%
#Two cases with where conditions 
 
#%sql SELECT * FROM payment WHERE customer_id = 1 OR customer_id = 2 AND amount = 0.99 # and works first
# %sql SELECT * FROM payment WHERE (customer_id = 1 OR customer_id = 2) AND amount = 0.99 # and works first
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 12 rows affected.
# [(2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (8, 1, 2, 2363, Decimal('0.99'), datetime.datetime(2005, 6, 18, 13, 33, 59), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (18, 1, 1, 8074, Decimal('0.99'), datetime.datetime(2005, 7, 28, 17, 33, 39), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (19, 1, 2, 8116, Decimal('0.99'), datetime.datetime(2005, 7, 28, 19, 20, 7), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (24, 1, 1, 11367, Decimal('0.99'), datetime.datetime(2005, 8, 2, 18, 1, 38), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (26, 1, 1, 12250, Decimal('0.99'), datetime.datetime(2005, 8, 18, 3, 57, 29), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
#Support manager asks you about the lists of all the payment of the customer 2, 6, 7 where the amount is either less than $2 or greater than $10
#It should be ordered by customer and amount in descending order 
# %sql SELECT * FROM payment WHERE (customer_id = 2 OR  customer_id = 6 OR  customer_id = 7 ) AND ( amount > 10 OR amount <=2)\
ORDER BY customer_id ASC, amount DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 20 rows affected.
# [(44, 2, 2, 9236, Decimal('10.99'), datetime.datetime(2005, 7, 30, 13, 47, 43), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (45, 2, 2, 9248, Decimal('0.99'), datetime.datetime(2005, 7, 30, 14, 14, 11), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (49, 2, 1, 10466, Decimal('0.99'), datetime.datetime(2005, 8, 1, 9, 45, 26), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (50, 2, 1, 10918, Decimal('0.99'), datetime.datetime(2005, 8, 2, 2, 10, 56), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (148, 6, 2, 916, Decimal('0.99'), datetime.datetime(2005, 5, 30, 11, 25, 1), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (151, 6, 1, 1966, Decimal('0.99'), datetime.datetime(2005, 6, 17, 9, 19, 45), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (152, 6, 1, 2345, Decimal('0.99'), datetime.datetime(2005, 6, 18, 12, 3, 23), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
# %sql SELECT COUNT(*) FROM payment WHERE amount BETWEEN 1 AND 2  AND payment_date BETWEEN '2005-07-06 23:14:21' AND '2005-08-20 05:53:31'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(9,)]

# %%
#Manager asks to list certain id's 
#%sql SELECT * FROM address WHERE district IN ('Attika', 'Kanagawa')
# %sql SELECT * FROM payment WHERE rental_id NOT IN (9236, 9248) LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %%
#find the list of customers with specific details
# %sql SELECT * FROM payment WHERE customer_id IN (1,2,3,4,5)\
AND amount IN (2.99, 0.99, 4.99)\
AND payment_date BETWEEN '2006-01-01 11:30:37' AND '2006-05-30'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(145, 5, 2, 13209, Decimal('0.99'), datetime.datetime(2006, 2, 14, 15, 16, 3), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %%
#Company wants to know what movies are in the inventory (lets use wildcards)
# %sql SELECT * FROM film WHERE description LIKE '%Drama%' AND title LIKE 'B%'  AND title LIKE '__K%'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(50, 'BAKED CLEOPATRA', 'A Stunning Drama of a Forensic Psychologist And a Husband who must Overcome a Waitress in A Monastery', 2006, 1, None, 3, Decimal('2.99'), 182, Decimal('20.99'), 'G', 'Commentaries,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (70, 'BIKINI BORROWERS', 'A Astounding Drama of a Astronaut And a Cat who must Discover a Woman in The First Manned Space Station', 2006, 1, None, 7, Decimal('4.99'), 142, Decimal('26.99'), 'NC-17', 'Commentaries,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))]

# %%
#How many customers are there with a firstname that is 3 letters long and either Z or S  as the last letter in the last name? 
# %sql SELECT * FROM customer WHERE first_name LIKE ('___') AND (last_name LIKE ('%Z') OR last_name LIKE ('%S'))
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(32, 1, 'AMY', 'LOPEZ', 'AMY.LOPEZ@sakilacustomer.org', 36, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (48, 1, 'ANN', 'EVANS', 'ANN.EVANS@sakilacustomer.org', 52, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))]

# %%
# %sql SELECT COUNT(*) AS Counts_of_Films  FROM film WHERE description LIKE '%Documentary%' AND title LIKE 'A%'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(3,)]

# %%
#How many movies are there that contain 'Feminist' in the description and has a title with starting A or Ending R. Use aliase.
# %sql SELECT COUNT(*) AS Counts_of_feminists FROM film WHERE description LIKE '%Feminist%' AND (title LIKE 'B%' OR title LIKE '%L')
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(7,)]

# %%
#Create a list of all customers where the firstname contains 'IC' and has an 'A' as the second letter. Order by lastname DESC.
# %sql SELECT * FROM customer WHERE first_name LIKE '%IC%' AND first_name LIKE '_A%' ORDER BY last_name DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(66, 2, 'JANICE', 'WARD', 'JANICE.WARD@sakilacustomer.org', 70, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20)),
#  (2, 1, 'PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 6, 1, datetime.datetime(2006, 2, 14, 22, 4, 36), datetime.datetime(2006, 2, 15, 4, 57, 20))]

# %%
#How many payments are there if where the amount is either 0 or is between 4 and 6 has happened in date''
# %sql SELECT * FROM payment WHERE (amount < 1  OR amount BETWEEN 4 AND 6) AND payment_date = '2005-06-18 08:41:48'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(7, 1, 1, 2308, Decimal('4.99'), datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %%
#Aggregate Functions

# %%
# %sql SELECT COUNT(amount) AS Count, SUM(amount) AS Sum,\
ROUND(AVG(amount), 2) AS Average FROM payment
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(266, Decimal('1084.34'), Decimal('4.08'))]

# %%
#Manager wants to find a better understanding of the film and requires MAX, MIN, SUM and AVERAGE of the replacement costs of films
# %sql SELECT MAX(replacement_cost) AS MAXIMUM, MIN(replacement_cost) AS MINIMUM,\
SUM(replacement_cost) AS SUM_OF_REPLACEMENT, ROUND(AVG(replacement_cost), 3) AS AVERAGE FROM film LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('29.99'), Decimal('9.99'), Decimal('3080.46'), Decimal('20.003'))]

# %%
# %sql SELECT customer_id, SUM(amount) AS SUM, MAX(amount) AS MAX FROM payment WHERE customer_id>3  GROUP BY customer_id ORDER BY SUM DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 7 rows affected.
# [(7, Decimal('151.67'), Decimal('8.99')),
#  (5, Decimal('144.62'), Decimal('9.99')),
#  (6, Decimal('93.72'), Decimal('7.99')),
#  (8, Decimal('92.76'), Decimal('9.99')),
#  (9, Decimal('89.77'), Decimal('7.99')),
#  (4, Decimal('81.78'), Decimal('8.99')),
#  (10, Decimal('46.87'), Decimal('7.99'))]

# %%
#Your manager wants to know which of the two employees is responsible for more payments? 
# %sql SELECT staff_id, SUM(amount) AS PAYMENT, COUNT(*) AS Payment_Occurence FROM payment GROUP BY staff_id  ORDER BY PAYMENT DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(1, Decimal('575.57'), 143), (2, Decimal('508.77'), 123)]

# %%
 # %sql SELECT *, DATE(last_update) AS last_updated FROM payment LIMIT 1
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30), datetime.date(2006, 2, 15))]

# %%
#Which of the employees has had the highest payment based on with one specific customer 
# %sql SELECT staff_id, customer_id, SUM(amount) as SUM, COUNT(*) FROM payment GROUP BY staff_id, customer_id ORDER BY COUNT(*) DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 20 rows affected.
# [(2, 5, Decimal('70.79'), 21),
#  (1, 7, Decimal('80.82'), 18),
#  (1, 1, Decimal('64.83'), 17),
#  (1, 5, Decimal('73.83'), 17),
#  (1, 6, Decimal('56.84'), 16),
#  (2, 1, Decimal('53.85'), 15),
#  (1, 2, Decimal('60.85'), 15),
#  (2, 7, Decimal('70.85'), 15),
#  (1, 3, Decimal('64.86'), 14),
#  (1, 8, Decimal('57.86'), 14),
#  (2, 2, Decimal('67.88'), 12),
#  (2, 3, Decimal('70.88'), 12),
#  (1, 4, Decimal('49.88'), 12),
#  (2, 6, Decimal('36.88'), 12),
#  (1, 9, Decimal('39.88'), 12),
#  (2, 9, Decimal('49.89'), 11),
#  (2, 4, Decimal('31.90'), 10),
#  (2, 8, Decimal('34.90'), 10),
#  (1, 10, Decimal('25.92'), 8),
#  (2, 10, Decimal('20.95'), 5)]

# %%
#Which employee has the highest sales   in a single day 
#Which employee has the most sales in a specific   day (not counting payment with amount = 0)
# %sql SELECT  staff_id AS Staff, SUM(amount)  AS SUM, DATE(payment_date) AS DATE, COUNT(*) AS COUNT FROM payment\
WHERE amount !=0 GROUP BY staff_id, DATE(payment_date)\
HAVING COUNT(*) > 2 AND DATE BETWEEN '2005-05-28' AND '2005-05-31' ORDER BY SUM(amount) DESC  LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(1, Decimal('14.97'), datetime.date(2005, 5, 31), 3),
#  (2, Decimal('8.97'), datetime.date(2005, 5, 30), 3)]

# %%
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 266 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (7, 1, 1, 2308, Decimal('4.99'), datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
#Find out the average payment amount  grouped by customer and day (with more than 3 paymentS)
# %sql SELECT staff_id, DATE(payment_date) AS DATE, ROUND(AVG(amount), 2) AS AVG, COUNT(*) AS COUNT FROM payment\
WHERE DATE(payment_date) IN ('2005-06-15', '2005-07-08') GROUP BY staff_id, DATE(payment_date) HAVING COUNT(*) > 3\
ORDER BY AVG DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(1, datetime.date(2005, 7, 8), Decimal('4.39'), 5),
#  (2, datetime.date(2005, 7, 8), Decimal('3.99'), 4)]

# %%
#INTERMEDIATE LEVEL

# %%
#There was a problem with sending an email. Task: All emails should be in lowercase,  FIRSTNAME  OT EXCEED 5 characters, and cut a certain part of it 
# %sql SELECT lower(first_name) AS First_name,lower(last_name) AS Last_name, LOWER(email) AS Email_2 FROM\
customer WHERE LENGTH(first_name)>5 LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('patricia', 'johnson', 'patricia.johnson@sakilacustomer.org'),
#  ('barbara', 'jones', 'barbara.jones@sakilacustomer.org'),
#  ('elizabeth', 'brown', 'elizabeth.brown@sakilacustomer.org'),
#  ('jennifer', 'davis', 'jennifer.davis@sakilacustomer.org'),
#  ('margaret', 'moore', 'margaret.moore@sakilacustomer.org')]

# %%
#Lets extract some characters  
# %sql SELECT RIGHT(LEFT(first_name, 5), 2) AS Extrac, first_name FROM customer LIMIT 2
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [('RY', 'MARY'), ('RI', 'PATRICIA')]

# %%
#Extract the last five characters and dot from email 
# %sql SELECT email, RIGHT(email, 5) as right, LEFT(RIGHT(email, 4),1) AS EXR FROM customer LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('MARY.SMITH@sakilacustomer.org', 'r.org', '.'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', 'r.org', '.'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', 'r.org', '.'),
#  ('BARBARA.JONES@sakilacustomer.org', 'r.org', '.'),
#  ('ELIZABETH.BROWN@sakilacustomer.org', 'r.org', '.')]

# %%
#Convert fist and last name with initials  
# %sql SELECT first_name, last_name, concat(LEFT(first_name, 1),'.',LEFT(last_name,1)) AS Initials FROM customer LIMIT 2
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [('MARY', 'SMITH', 'M.S'), ('PATRICIA', 'JOHNSON', 'P.J')]

# %%
#Create an anonimyzed version of email adress 

#Chahge MARY.SMITH@sakilacustomer.org  to M***@sakilacustomer.org

# %sql SELECT CONCAT(LEFT(email, 1), '***' ,LOWER(RIGHT(email, 20))) AS Anonimyzed FROM customer  LIMIT 2
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [('M***h@sakilacustomer.org',), ('P***n@sakilacustomer.org',)]

# %%
#Lets find out all the names and lastnames of emails
# %sql SELECT LEFT(email, POSITION(last_name IN email)-2 ) AS F,\
LEFT(email, POSITION('@' IN email)-1 ) AS F_L,\
email FROM customer
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 89 rows affected.
# [('MARY', 'MARY.SMITH', 'MARY.SMITH@sakilacustomer.org'),
#  ('PATRICIA', 'PATRICIA.JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org'),
#  ('LINDA', 'LINDA.WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org'),
#  ('BARBARA', 'BARBARA.JONES', 'BARBARA.JONES@sakilacustomer.org'),
#  ('ELIZABETH', 'ELIZABETH.BROWN', 'ELIZABETH.BROWN@sakilacustomer.org'),
#  ('JENNIFER', 'JENNIFER.DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org'),
#  ('MARIA', 'MARIA.MILLER', 'MARIA.MILLER@sakilacustomer.org'),
#  ('SUSAN', 'SUSAN.WILSON', 'SUSAN.WILSON@sakilacustomer.org'),
#  ('MARGARET', 'MARGARET.MOORE', 'MARGARET.MOORE@sakilacustomer.org'),
#  ('DOROTHY', 'DOROTHY.TAYLOR', 'DOROTHY.TAYLOR@sakilacustomer.org'),
#  ('LISA', 'LISA.ANDERSON', 'LISA.ANDERSON@sakilacustomer.org'),
#  ('NANCY', 'NANCY.THOMAS', 'NANCY.THOMAS@sakilacustomer.org'),
#  ('KAREN', 'KAREN.JACKSON', 'KAREN.JACKSON@sakilacustomer.org'),
# ...

# %%
#Extract the first name from the email and concatinate it with the given last name
# %sql SELECT email, last_name, CONCAT(last_name, '.', LEFT(email,POSITION(last_name IN email)-2 ))\
AS Name_Surname FROM customer LIMIT 4
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 4 rows affected.
# [('MARY.SMITH@sakilacustomer.org', 'SMITH', 'SMITH.MARY'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', 'JOHNSON', 'JOHNSON.PATRICIA'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', 'WILLIAMS', 'WILLIAMS.LINDA'),
#  ('BARBARA.JONES@sakilacustomer.org', 'JONES', 'JONES.BARBARA')]

# %%
#let's extract a specific word with the substring function in different way
# %sql SELECT email, SUBSTRING(email FROM POSITION('.' IN email)+1 FOR LENGTH(last_name)) AS Extracted FROM customer  LIMIT 3
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [('MARY.SMITH@sakilacustomer.org', 'SMITH'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', 'JOHNSON'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', 'WILLIAMS')]

# %%
#let's create an anonymized version of the email addresses again 
# %sql SELECT  email, CONCAT(SUBSTRING(email FROM POSITION('.' IN email)-4 FOR 1), '***',\
                           SUBSTRING(email FROM POSITION('.' IN email) FOR 2),\
                           '***',\
                           SUBSTRING(email FROM POSITION('@' IN email))) AS Extracted FROM customer LIMIT 3
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [('MARY.SMITH@sakilacustomer.org', 'M***.S***@sakilacustomer.org'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', 'I***.J***@sakilacustomer.org'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', 'I***.W***@sakilacustomer.org')]

# %%
#let's create an anonymized version of the email addresses again 
# %sql SELECT  email, CONCAT('***', SUBSTRING(email FROM POSITION('.' IN email)-1 FOR 1),\
                           SUBSTRING(email FROM POSITION('.' IN email) FOR 2),\
                           '***',\
                           SUBSTRING(email FROM POSITION('@' IN email))) AS Extracted FROM customer LIMIT 3
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [('MARY.SMITH@sakilacustomer.org', '***Y.S***@sakilacustomer.org'),
#  ('PATRICIA.JOHNSON@sakilacustomer.org', '***A.J***@sakilacustomer.org'),
#  ('LINDA.WILLIAMS@sakilacustomer.org', '***A.W***@sakilacustomer.org')]

# %%
#What is the day of the week with the highest sales amount?
# %sql SELECT EXTRACT(day from payment_date) AS days, COUNT(*) AS count FROM payment\
GROUP BY EXTRACT(day from payment_date) ORDER BY count DESC LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(30, 23),
#  (28, 22),
#  (18, 22),
#  (2, 20),
#  (21, 17),
#  (19, 17),
#  (17, 17),
#  (20, 16),
#  (27, 16),
#  (29, 16)]

# %%
#What is the month with the highest total payment amount ?

# %%
# %sql SELECT EXTRACT(month from payment_date) AS month_date, SUM(amount) as Sum FROM payment\
GROUP BY EXTRACT(month from payment_date) ORDER BY Sum  DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(7, Decimal('454.92')),
#  (8, Decimal('386.07')),
#  (6, Decimal('160.58')),
#  (5, Decimal('76.79')),
#  (2, Decimal('5.98'))]

# %%
#What is the highest amount one customer has spent in a week? 
# %sql SELECT customer_id, EXTRACT(week from payment_date) AS week, SUM(amount) AS Sum FROM payment\
GROUP BY customer_id, EXTRACT(week from payment_date) ORDER BY Sum DESC LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(2, 30, Decimal('62.89')),
#  (3, 30, Decimal('50.91')),
#  (7, 31, Decimal('34.94')),
#  (7, 27, Decimal('28.95')),
#  (4, 33, Decimal('28.94')),
#  (1, 24, Decimal('27.94')),
#  (5, 33, Decimal('26.94')),
#  (7, 33, Decimal('26.94')),
#  (8, 27, Decimal('23.93')),
#  (3, 24, Decimal('22.97'))]

# %%
#Data types formattiong functions 
#%sql SELECT *, DATE(payment_date)as date FROM payment 
# %sql SELECT *, EXTRACT(month from payment_date) AS month, DATE_FORMAT(payment_date, '%d, %m-%Y') AS New_Date FROM payment LIMIT 2
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30), 5, '25, 05-2005'),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30), 5, '28, 05-2005')]

# %%
#Extract date(with characters) from payment using TO_CHAR 
# %sql SELECT SUM(amount) AS Sum, DATE_FORMAT(payment_date, '%D, %M %Y')\
AS New_Date FROM payment GROUP BY DATE_FORMAT(payment_date, '%D, %M %Y') ORDER BY Sum DESC LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(Decimal('65.84'), '2nd, August 2005'),
#  (Decimal('63.88'), '21st, August 2005'),
#  (Decimal('60.88'), '30th, July 2005'),
#  (Decimal('56.88'), '18th, August 2005'),
#  (Decimal('52.87'), '1st, August 2005')]

# %%
#https://www.sqlines.com/oracle-to-mysql/to_char_datetime 
#Lets sum payments and format date in three different column   

#%sql SELECT  CURRENT_TIMESTAMP, payment_date, EXTRACT(day from CURRENT_TIMESTAMP - payment_date)  FROM payment

# %%
# %sql SELECT payment_date, last_update, CONCAT(DATEDIFF(last_update, payment_date), ' days ')\
AS Difference FROM payment LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30), '266 days '),
#  (datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30), '263 days '),
#  (datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30), '245 days '),
#  (datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30), '245 days '),
#  (datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30), '245 days '),
#  (datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30), '244 days '),
#  (datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30), '242 days '),
#  (datetime.datetime(2005, 6, 18, 13, 33, 59), datetime.datetime(2006, 2, 15, 22, 12, 30), '242 days '),
# ...

# %%
#Increase the  rental rate of films by  40% decreare by 30% AND 1$  
# %sql SELECT film_id, rental_rate, ROUND(rental_rate * 1.4, 2) AS Perc_change_40,\
rental_rate+1 AS New_Rental_1 FROM film LIMIT 5
#CEILING(rental_rate / 1.3)-0.1 AS Perc_change_30,\
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(1, Decimal('0.99'), Decimal('1.39'), Decimal('1.99')),
#  (2, Decimal('4.99'), Decimal('6.99'), Decimal('5.99')),
#  (3, Decimal('2.99'), Decimal('4.19'), Decimal('3.99')),
#  (4, Decimal('2.99'), Decimal('4.19'), Decimal('3.99')),
#  (5, Decimal('2.99'), Decimal('4.19'), Decimal('3.99'))]

# %%
# %sql SELECT * FROM film LIMIT 1
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42))]

# %%
#Create a list of the films where the rental rate is less than 4% of the replacement cost, because we are intented to increase the prices that are more expensive

# %sql SELECT film_id, ROUND(rental_rate/replacement_cost*100, 2) AS perc FROM film\
WHERE ROUND(rental_rate/replacement_cost*100, 2)<4
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 15 rows affected.
# [(18, Decimal('3.54')),
#  (34, Decimal('3.30')),
#  (38, Decimal('3.81')),
#  (52, Decimal('3.30')),
#  (64, Decimal('3.67')),
#  (66, Decimal('3.54')),
#  (85, Decimal('3.30')),
#  (97, Decimal('3.96')),
#  (101, Decimal('3.67')),
#  (110, Decimal('3.81')),
#  (114, Decimal('3.67')),
#  (118, Decimal('3.67')),
#  (130, Decimal('3.96')),
#  (132, Decimal('3.81')),
#  (142, Decimal('3.96'))]

# %%
# %sql SELECT * FROM address LIMIT 3
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [(524, '680 A Corua (La Corua) Manor', None, 'Attika', 482, '49806', ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (525, '1949 Sanya Street', None, 'Kanagawa', 224, '61244', ' ', datetime.datetime(2006, 2, 15, 4, 45, 30)),
#  (526, '617 Klerksdorp Place', None, 'England', 366, '94707', ' ', datetime.datetime(2006, 2, 15, 4, 45, 30))]

# %%
# %sql SELECT rating, COUNT(*) AS Count FROM film GROUP BY rating
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('PG', 29), ('G', 39), ('NC-17', 35), ('PG-13', 25), ('R', 26)]

# %%
#Additional tricks for data analyses  

# %sql SELECT COUNT(*) AS count,\
CASE WHEN city_id < 200 THEN 'Id is low'\
WHEN city_id BETWEEN 200 AND 300 THEN 'Id is medium'\
ELSE 'Id is high'\
END\
AS FUNC FROM address GROUP BY FUNC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [(32, 'Id is high'), (18, 'Id is low'), (11, 'Id is medium')]

# %%
# %sql SELECT address, city_id,\
CASE WHEN city_id < 200 THEN 'Id is low'\
WHEN city_id BETWEEN 200 AND 300 THEN 'Id is medium'\
ELSE 'Id is high'\
END\
AS FUNC FROM address LIMIT 15
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 15 rows affected.
# [('680 A Corua (La Corua) Manor', 482, 'Id is high'),
#  ('1949 Sanya Street', 224, 'Id is medium'),
#  ('617 Klerksdorp Place', 366, 'Id is high'),
#  ('1993 0 Loop', 588, 'Id is high'),
#  ('1176 Southend-on-Sea Manor', 458, 'Id is high'),
#  ('600 Purnea (Purnia) Avenue', 571, 'Id is high'),
#  ('1003 Qinhuangdao Street', 419, 'Id is high'),
#  ('1986 Sivas Place', 551, 'Id is high'),
#  ('1427 Tabuk Place', 101, 'Id is low'),
#  ('556 Asuncin Way', 339, 'Id is high'),
#  ('486 Ondo Parkway', 67, 'Id is low'),
#  ('635 Brest Manor', 75, 'Id is low'),
#  ('166 Jinchang Street', 165, 'Id is low'),
#  ('958 Sagamihara Lane', 287, 'Id is medium'),
#  ('1817 Livorno Way', 100, 'Id is low')]

# %%
# %sql SELECT title, CASE\
WHEN rating IN('PG','G') OR length > 150 THEN 'High rated'\
WHEN description LIKE '%Drama%' AND length > 90 THEN 'The drama is long'\
WHEN rental_rate < 1 THEN 'Very Cheap'\
END AS Rate FROM film WHERE CASE\
WHEN rating IN('PG','G') OR length > 150 THEN 'High rated'\
WHEN description LIKE '%Drama%' AND length > 90 THEN 'The drama is long'\
WHEN rental_rate < 1 THEN 'Very Cheap'\
END IS NOT  NULL LIMIT 20
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 20 rows affected.
# [('ACADEMY DINOSAUR', 'High rated'),
#  ('ACE GOLDFINGER', 'High rated'),
#  ('AFFAIR PREJUDICE', 'High rated'),
#  ('AFRICAN EGG', 'High rated'),
#  ('AGENT TRUMAN', 'High rated'),
#  ('ALAMO VIDEOTAPE', 'High rated'),
#  ('ALASKA PHANTOM', 'High rated'),
#  ('ALI FOREVER', 'High rated'),
#  ('ALICE FANTASIA', 'The drama is long'),
#  ('ALLEY EVOLUTION', 'High rated'),
#  ('ALONE TRIP', 'Very Cheap'),
#  ('ALTER VICTORY', 'Very Cheap'),
#  ('AMADEUS HOLY', 'High rated'),
#  ('AMERICAN CIRCUS', 'The drama is long'),
#  ('AMISTAD MIDSUMMER', 'High rated'),
#  ('ANACONDA CONFESSIONS', 'Very Cheap'),
#  ('ANALYZE HOOSIERS', 'High rated'),
#  ('ANGELS LIFE', 'High rated'),
#  ('ANNIE IDENTITY', 'High rated'),
#  ('ANONYMOUS HUMAN', 'High rated')]

# %%
# %sql SELECT rating, SUM(CASE\
WHEN rating IN ('PG', 'G') THEN 1\
ELSE 0\
END) AS Counts FROM film GROUP BY rating
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('PG', Decimal('29')),
#  ('G', Decimal('39')),
#  ('NC-17', Decimal('0')),
#  ('PG-13', Decimal('0')),
#  ('R', Decimal('0'))]

# %%
# %sql SELECT rating, COUNT(*) FROM FILM GROUP BY rating
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('PG', 29), ('G', 39), ('NC-17', 35), ('PG-13', 25), ('R', 26)]

# %%
#let's format it as in columns
# %sql SELECT\
    SUM(CASE WHEN rating = 'PG' THEN  1  ELSE 0 END) AS PG,\
    SUM(CASE WHEN rating = 'G' THEN  1  ELSE 0 END) AS G,\
    SUM(CASE WHEN rating = 'R' THEN  1  ELSE 0 END) AS R,\
    SUM(CASE WHEN rating = 'NC-17' THEN  1  ELSE 0 END) AS NC,\
    SUM(CASE WHEN rating = 'PG-13' THEN  1  ELSE 0 END) AS PG_1 FROM film
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('29'), Decimal('39'), Decimal('26'), Decimal('35'), Decimal('25'))]

# %%
#Lets use COALESCE and Change data type to fill null values in a timestamp table 
# %sql SELECT return_date, COALESCE(CAST(return_date AS DATE), 'Not arrived') AS CHANGED  FROM rental
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 102 rows affected.
# [(datetime.datetime(2005, 5, 26, 22, 4, 30), '2005-05-26'),
#  (datetime.datetime(2005, 5, 28, 19, 40, 33), '2005-05-28'),
#  (datetime.datetime(2005, 6, 1, 22, 12, 39), '2005-06-01'),
#  (datetime.datetime(2005, 6, 3, 1, 43, 41), '2005-06-03'),
#  (datetime.datetime(2005, 6, 2, 4, 33, 21), '2005-06-02'),
#  (datetime.datetime(2005, 5, 27, 1, 32, 7), '2005-05-27'),
#  (datetime.datetime(2005, 5, 29, 20, 34, 53), '2005-05-29'),
#  (datetime.datetime(2005, 5, 27, 23, 33, 46), '2005-05-27'),
#  (datetime.datetime(2005, 5, 28, 0, 22, 40), '2005-05-28'),
#  (datetime.datetime(2005, 5, 31, 22, 44, 21), '2005-05-31'),
#  (datetime.datetime(2005, 6, 2, 20, 56, 2), '2005-06-02'),
#  (datetime.datetime(2005, 5, 30, 5, 44, 27), '2005-05-30'),
#  (datetime.datetime(2005, 5, 30, 4, 28, 55), '2005-05-30'),
#  (datetime.datetime(2005, 5, 26, 2, 56, 15), '2005-05-26'),
# ...

# %%
#Replace certain values in a column

# %%
#After cleaning and replacing the data you coul cast it as 
#CAST(REPLACE(column, 'value1', 'value2') AS BIGINT, VARCHAR, INT)

# %%
# %sql SELECT description, rating,\
REPLACE(rating, 'PG', 'Rating - PG')\
AS Changed_rating\
FROM film WHERE description LIKE '%Documentary%'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 12 rows affected.
# [('A Fanciful Documentary of a Frisbee And a Lumberjack who must Chase a Monkey in A Shark Tank', 'G', 'G'),
#  ('A Fast-Paced Documentary of a Pastry Chef And a Dentist who must Pursue a Forensic Psychologist in The Gulf of Mexico', 'G', 'G'),
#  ('A Fanciful Documentary of a Mad Cow And a Womanizer who must Find a Dentist in Berlin', 'PG', 'Rating - PG'),
#  ('A Thrilling Documentary of a Composer And a Monkey who must Find a Feminist in California', 'G', 'G'),
#  ('A Fanciful Documentary of a Womanizer And a Boat who must Defeat a Madman in The First Manned Space Station', 'R', 'R'),
#  ('A Thrilling Documentary of a Car And a Student who must Sink a Hunter in The Canadian Rockies', 'G', 'G'),
#  ('A Emotional Documentary of a Student And a Girl who must Build a Boat in Nigeria', 'G', 'G'),
# ...

# %%
# %sql SELECT  DISTINCT(p.customer_id), c.first_name, c.last_name FROM payment p\
INNER JOIN customer c ON p.customer_id = c.customer_id
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(1, 'MARY', 'SMITH'),
#  (2, 'PATRICIA', 'JOHNSON'),
#  (3, 'LINDA', 'WILLIAMS'),
#  (4, 'BARBARA', 'JONES'),
#  (5, 'ELIZABETH', 'BROWN'),
#  (6, 'JENNIFER', 'DAVIS'),
#  (7, 'MARIA', 'MILLER'),
#  (8, 'SUSAN', 'WILSON'),
#  (9, 'MARGARET', 'MOORE'),
#  (10, 'DOROTHY', 'TAYLOR')]

# %%
#Company wants to understand in which price group film makers made a lot sell 
# %sql SELECT p.amount, COUNT(*) AS count FROM payment p INNER JOIN\
customer c ON p.customer_id = c.customer_id GROUP BY p.amount ORDER BY 2 DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 11 rows affected.
# [(Decimal('2.99'), 63),
#  (Decimal('4.99'), 54),
#  (Decimal('0.99'), 52),
#  (Decimal('5.99'), 29),
#  (Decimal('3.99'), 17),
#  (Decimal('6.99'), 15),
#  (Decimal('1.99'), 13),
#  (Decimal('7.99'), 11),
#  (Decimal('8.99'), 7),
#  (Decimal('9.99'), 3),
#  (Decimal('10.99'), 2)]

# %%
# %sql SELECT  c.first_name, c.last_name, a_t.address, a_t.postal_code FROM customer c\
INNER JOIN address a_t ON a_t.address_id = c.address_id WHERE a_t.address LIKE '%Iligan Lane%'
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [('HELEN', 'HARRIS', '419 Iligan Lane', '72878')]

# %%
#The county wants to customize campaings  from customers
# %sql SELECT c.first_name, c.last_name, c.email, c_ci.city, a.address, c_co.country  FROM customer c LEFT JOIN address a ON c.address_id =a.address_id\
LEFT JOIN city c_ci ON a.address_id =c_ci.city_id LEFT JOIN country c_co ON a.address_id = c_co.country_id
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 89 rows affected.
# [('MARY', 'SMITH', 'MARY.SMITH@sakilacustomer.org', 'Adana', '1913 Hanoi Way', 'Anguilla'),
#  ('PATRICIA', 'JOHNSON', 'PATRICIA.JOHNSON@sakilacustomer.org', 'Addis Abeba', '1121 Loja Avenue', 'Argentina'),
#  ('LINDA', 'WILLIAMS', 'LINDA.WILLIAMS@sakilacustomer.org', 'Aden', '692 Joliet Street', 'Armenia'),
#  ('BARBARA', 'JONES', 'BARBARA.JONES@sakilacustomer.org', 'Adoni', '1566 Inegl Manor', 'Australia'),
#  ('ELIZABETH', 'BROWN', 'ELIZABETH.BROWN@sakilacustomer.org', 'Ahmadnagar', '53 Idfu Parkway', 'Austria'),
#  ('JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 'Akishima', '1795 Santiago de Compostela Way', 'Azerbaijan'),
#  ('MARIA', 'MILLER', 'MARIA.MILLER@sakilacustomer.org', 'Akron', '900 Santiago de Compostela Parkway', 'Bahrain'),
#  ('SUSAN', 'WILSON', 'SUSAN.WILSON@sakilacustomer.org', 'al-Ayn', '478 Joliet Way', 'Bangladesh'),
# ...

# %%
#Find out the person who lives in Azerbaijan  
# %sql SELECT c.first_name,  c.last_name,   c.email, c_co.country  FROM customer c LEFT JOIN address a ON c.address_id =a.address_id\
LEFT JOIN city c_ci ON a.address_id =c_ci.city_id LEFT JOIN country c_co ON a.address_id = c_co.country_id WHERE country = 'Azerbaijan'\
GROUP BY c.first_name, c.last_name,  c.email, c_co.country
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [('JENNIFER', 'DAVIS', 'JENNIFER.DAVIS@sakilacustomer.org', 'Azerbaijan')]

# %%
# %sql SELECT first_name,'actor' from actor\
UNION\
SELECT first_name, 'customer' from customer\
UNION\
SELECT UPPER(first_name), 'staff' from staff ORDER BY 1 DESC LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [('ZERO', 'actor'),
#  ('WOODY', 'actor'),
#  ('WANDA', 'customer'),
#  ('VIVIEN', 'actor'),
#  ('VIRGINIA', 'customer'),
#  ('VAL', 'actor'),
#  ('UMA', 'actor'),
#  ('TOM', 'actor'),
#  ('TIM', 'actor'),
#  ('THERESA', 'customer')]

# %%
#A manager asks to return all payments where payments amount is greater than all payments  
# %sql SELECT * FROM payment WHERE amount > (SELECT AVG(amount) FROM payment ) LIMIT 5
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (7, 1, 1, 2308, Decimal('4.99'), datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (10, 1, 2, 4526, Decimal('5.99'), datetime.datetime(2005, 7, 8, 3, 17, 5), datetime.datetime(2006, 2, 15, 22, 12, 30))]

# %%
#We want all of the payments of customer Patricia
# %sql SELECT * FROM payment WHERE customer_id = (SELECT customer_id FROM customer WHERE first_name = 'PATRICIA')
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 27 rows affected.
# [(33, 2, 1, 320, Decimal('4.99'), datetime.datetime(2005, 5, 27, 0, 9, 24), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (34, 2, 1, 2128, Decimal('2.99'), datetime.datetime(2005, 6, 17, 20, 54, 58), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (35, 2, 1, 5636, Decimal('2.99'), datetime.datetime(2005, 7, 10, 6, 31, 24), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (36, 2, 1, 5755, Decimal('6.99'), datetime.datetime(2005, 7, 10, 12, 38, 56), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (37, 2, 2, 7346, Decimal('4.99'), datetime.datetime(2005, 7, 27, 14, 30, 42), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (38, 2, 1, 7376, Decimal('5.99'), datetime.datetime(2005, 7, 27, 15, 23, 2), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (39, 2, 2, 7459, Decimal('5.99'), datetime.datetime(2005, 7, 27, 18, 40, 20), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
# %sql SELECT * FROM payment WHERE customer_id IN (SELECT customer_id FROM customer WHERE first_name LIKE '%ARA'  )
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 22 rows affected.
# [(86, 4, 1, 1297, Decimal('4.99'), datetime.datetime(2005, 6, 15, 9, 31, 28), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (87, 4, 1, 1633, Decimal('0.99'), datetime.datetime(2005, 6, 16, 8, 8, 40), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (88, 4, 2, 1707, Decimal('2.99'), datetime.datetime(2005, 6, 16, 14, 1, 27), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (89, 4, 2, 1735, Decimal('0.99'), datetime.datetime(2005, 6, 16, 15, 51, 52), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (90, 4, 2, 2043, Decimal('0.99'), datetime.datetime(2005, 6, 17, 14, 31, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (91, 4, 1, 2642, Decimal('5.99'), datetime.datetime(2005, 6, 19, 9, 39, 1), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (92, 4, 1, 7660, Decimal('2.99'), datetime.datetime(2005, 7, 28, 2, 10, 10), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
##Return all of the films that are available in the inventory in store 2 more than 3 times
#%sql SELECT film_id, COUNT(*)  FROM inventory WHERE store_id = 2 GROUP BY film_id HAVING COUNT(*)> 3
# %sql SELECT * FROM film WHERE film_id IN (SELECT film_id FROM inventory WHERE store_id = 2\
GROUP BY film_id HAVING COUNT(*)> 3)
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 6 rows affected.
# [(1, 'ACADEMY DINOSAUR', 'A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies', 2006, 1, None, 6, Decimal('0.99'), 86, Decimal('20.99'), 'PG', 'Deleted Scenes,Behind the Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (3, 'ADAPTATION HOLES', 'A Astounding Reflection of a Lumberjack And a Car who must Sink a Lumberjack in A Baloon Factory', 2006, 1, None, 7, Decimal('2.99'), 50, Decimal('18.99'), 'NC-17', 'Trailers,Deleted Scenes', datetime.datetime(2006, 2, 15, 5, 3, 42)),
#  (8, 'AIRPORT POLLOCK', 'A Epic Tale of a Moose And a Girl who must Confront a Monkey in Ancient India', 2006, 1, None, 6, Decimal('4.99'), 54, Decimal('15.99'), 'R', 'Trailers', datetime.datetime(2006, 2, 15, 5, 3, 42)),
# ...

# %%
#Return First names and lastnames of customers that have made payment on '2005-06-15'
# %sql SELECT first_name, last_name FROM customer WHERE customer_id IN\
(SELECT customer_id FROM payment WHERE DATE(payment_date) = '2005-06-15')
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 4 rows affected.
# [('MARY', 'SMITH'),
#  ('BARBARA', 'JONES'),
#  ('ELIZABETH', 'BROWN'),
#  ('SUSAN', 'WILSON')]

# %%
#Return First names and lastnames of customers that have spent more than 100$
# %sql SELECT customer_id, SUM(amount), COUNT(*) FROM payment GROUP BY customer_id HAVING SUM(amount)> 100
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [(1, Decimal('118.68'), 32),
#  (2, Decimal('128.73'), 27),
#  (3, Decimal('135.74'), 26),
#  (5, Decimal('144.62'), 38),
#  (7, Decimal('151.67'), 33)]

# %%
#%sql SELECT customer_id FROM customer INNER JOIN address ON customer.customer_id = address.address_id

# %%
#Return First names and lastnames of customers that are from Parkway and spent more than 100$ 
# %sql SELECT customer_id, first_name,last_name  FROM customer WHERE customer_id IN\
(SELECT customer_id FROM payment GROUP BY customer_id HAVING SUM(amount)> 100)\
OR\
customer_id IN (SELECT customer_id FROM customer INNER JOIN address ON customer.customer_id = address.address_id WHERE address LIKE '%Parkway%')
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [(1, 'MARY', 'SMITH'),
#  (2, 'PATRICIA', 'JOHNSON'),
#  (3, 'LINDA', 'WILLIAMS'),
#  (5, 'ELIZABETH', 'BROWN'),
#  (7, 'MARIA', 'MILLER'),
#  (546, 'KELLY', 'KNOTT'),
#  (547, 'KURT', 'EMMONS'),
#  (555, 'DWIGHT', 'LOMBARDI'),
#  (559, 'EVERETT', 'BANDA'),
#  (574, 'JULIAN', 'VEST')]

# %%
 #Use subquery  with from

# %%
#Retrieve the total average of spending, two step calculation  
# %sql SELECT ROUND(AVG(sum_of_all),2) AS AVG FROM\
(SELECT customer_id, SUM(amount) AS sum_of_all  FROM payment GROUP BY customer_id) AS total_sum
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('108.43'),)]

# %%
#What is the average daily revenue  
# %sql SELECT ROUND(AVG(Sum),2) AS AVG FROM\
(SELECT SUM(amount) AS Sum, DATE(payment_date) AS Date FROM payment GROUP BY DATE(payment_date)) AS Date
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('30.12'),)]

# %%
#Let's use subquery as an expression

# %%
#%sql SELECT *, (SELECT  country_id  FROM city LIMIT 1) AS AD_COL FROM city
# %sql SELECT *, (SELECT ROUND(AVG(country_id),2) FROM city) AS AD_COL FROM city
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 80 rows affected.
# [(1, 'A Corua (La Corua)', 87, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (2, 'Abha', 82, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (3, 'Abu Dhabi', 101, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (4, 'Acua', 60, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (5, 'Adana', 97, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (6, 'Addis Abeba', 31, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (7, 'Aden', 107, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (8, 'Adoni', 44, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (9, 'Ahmadnagar', 44, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
#  (10, 'Akishima', 50, datetime.datetime(2006, 2, 15, 4, 45, 25), Decimal('52.89')),
# ...

# %%
#Select all payments which are below the maximum and extract considering difference between maximum and actual data    

# %sql SELECT *, (SELECT MAX(amount) FROM payment)- amount AS  payment FROM payment
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 266 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('8.00')),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('10.00')),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('5.00')),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('10.00')),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('1.00')),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('6.00')),
# ...

# %%
# Retrieve the list of customers whose payment amount is maximum by customer_id
# %sql SELECT * FROM payment p WHERE amount = (SELECT MAX(amount) FROM\
                                             payment p2 WHERE p.customer_id = p2.customer_id)
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 13 rows affected.
# [(5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (44, 2, 2, 9236, Decimal('10.99'), datetime.datetime(2005, 7, 30, 13, 47, 43), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (69, 3, 2, 7503, Decimal('10.99'), datetime.datetime(2005, 7, 27, 20, 23, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (101, 4, 2, 12294, Decimal('8.99'), datetime.datetime(2005, 8, 18, 5, 14, 44), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (137, 5, 1, 12145, Decimal('9.99'), datetime.datetime(2005, 8, 18, 0, 10, 4), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (157, 6, 1, 6248, Decimal('7.99'), datetime.datetime(2005, 7, 11, 15, 1, 54), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (170, 6, 1, 14329, Decimal('7.99'), datetime.datetime(2005, 8, 21, 8, 22, 56), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
# Retrieve the list of customers whose payment amount is higher than the average by customer_id
# %sql SELECT * FROM payment p WHERE amount > (SELECT AVG(amount) FROM\
                                             payment p2 WHERE p.customer_id = p2.customer_id )
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 129 rows affected.
# [(3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (7, 1, 1, 2308, Decimal('4.99'), datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (9, 1, 1, 3284, Decimal('3.99'), datetime.datetime(2005, 6, 21, 6, 24, 45), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (10, 1, 2, 4526, Decimal('5.99'), datetime.datetime(2005, 7, 8, 3, 17, 5), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (11, 1, 1, 4611, Decimal('5.99'), datetime.datetime(2005, 7, 8, 7, 33, 56), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...

# %%
#Show only those movie titles with the lowest replacement costs  for in each rating category
# %sql SELECT title, film_id, replacement_cost, rating FROM film f1 WHERE\
replacement_cost = (SELECT MIN(replacement_cost) FROM FILM f2 WHERE f1.rating = f2.rating )
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 9 rows affected.
# [('ALIEN CENTER', 15, Decimal('10.99'), 'NC-17'),
#  ('AMISTAD MIDSUMMER', 22, Decimal('10.99'), 'G'),
#  ('ANACONDA CONFESSIONS', 23, Decimal('9.99'), 'R'),
#  ('ARMAGEDDON LOST', 39, Decimal('10.99'), 'G'),
#  ('ARTIST COLDBLOODED', 42, Decimal('10.99'), 'NC-17'),
#  ('BALLOON HOMEWARD', 51, Decimal('10.99'), 'NC-17'),
#  ('BLADE POLISH', 79, Decimal('10.99'), 'PG-13'),
#  ('CATCH AMISTAD', 128, Decimal('10.99'), 'G'),
#  ('CIDER DESIRE', 150, Decimal('9.99'), 'PG')]

# %%
#Lets find the maximum length for each film by rating 
# %sql SELECT title, film_id, length, rating FROM film f1 WHERE\
length = (SELECT MAX(length) FROM film f2 WHERE f1.rating = f2.rating)
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 5 rows affected.
# [('ALLEY EVOLUTION', 16, 180, 'NC-17'),
#  ('ANALYZE HOOSIERS', 24, 181, 'R'),
#  ('BORN SPINAL', 88, 179, 'PG'),
#  ('CATCH AMISTAD', 128, 183, 'G'),
#  ('CHICAGO NORTH', 141, 185, 'PG-13')]

# %%
#Lets find the maximum rental_rate cost for each film by category_id and add to additional column 
# %sql SELECT *, (SELECT MAX(amount) FROM payment p2 WHERE\
                p1.customer_id = p2.customer_id) AS ad_col FROM payment p1
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 266 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30), Decimal('9.99')),
# ...

# %%
#Show all the payments plus the total amount for every customer and the number of payments 
# %sql SELECT payment_id, customer_id, staff_id, (SELECT SUM(amount) FROM payment p1\
                                                WHERE p1.customer_id = p2.customer_id) AS Sum,(SELECT COUNT(amount) FROM payment p1 WHERE p1.customer_id = p2.customer_id) AS Count\
FROM payment p2
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 266 rows affected.
# [(1, 1, 1, Decimal('118.68'), 32),
#  (2, 1, 1, Decimal('118.68'), 32),
#  (3, 1, 1, Decimal('118.68'), 32),
#  (4, 1, 2, Decimal('118.68'), 32),
#  (5, 1, 2, Decimal('118.68'), 32),
#  (6, 1, 1, Decimal('118.68'), 32),
#  (7, 1, 1, Decimal('118.68'), 32),
#  (8, 1, 2, Decimal('118.68'), 32),
#  (9, 1, 1, Decimal('118.68'), 32),
#  (10, 1, 2, Decimal('118.68'), 32),
#  (11, 1, 1, Decimal('118.68'), 32),
#  (12, 1, 1, Decimal('118.68'), 32),
#  (13, 1, 1, Decimal('118.68'), 32),
#  (14, 1, 1, Decimal('118.68'), 32),
#  (15, 1, 2, Decimal('118.68'), 32),
#  (16, 1, 1, Decimal('118.68'), 32),
#  (17, 1, 2, Decimal('118.68'), 32),
#  (18, 1, 1, Decimal('118.68'), 32),
#  (19, 1, 2, Decimal('118.68'), 32),
#  (20, 1, 2, Decimal('118.68'), 32),
#  (21, 1, 2, Decimal('118.68'), 32),
#  (22, 1, 2, Decimal('118.68'), 32),
#  (23, 1, 2, Decimal('118.68'), 32),
#  (24, 1, 1, Decimal('118.68'), 32),
# ...

# %%
title, replacemet_cost, rating, avg

# %%
#Show only those films with the hishest replacement costs in their category plus average replacement cost in their rating category 
# %sql SELECT title,  replacement_cost, rating, (SELECT ROUND(AVG(replacement_cost),2) FROM film) AS AVG FROM film f1 WHERE replacement_cost = (SELECT MAX(replacement_cost) FROM\
film f2 WHERE f2.rating=f1.rating)
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 6 rows affected.
# [('ARABIA DOGMA', Decimal('29.99'), 'NC-17', Decimal('20.00')),
#  ('ARIZONA BANG', Decimal('28.99'), 'PG', Decimal('20.00')),
#  ('BALLROOM MOCKINGBIRD', Decimal('29.99'), 'G', Decimal('20.00')),
#  ('BLINDNESS GUN', Decimal('29.99'), 'PG-13', Decimal('20.00')),
#  ('BONNIE HOLOCAUST', Decimal('29.99'), 'G', Decimal('20.00')),
#  ('CHARIOTS CONSPIRACY', Decimal('29.99'), 'R', Decimal('20.00'))]

# %%
#Show only those payments with the highest payment for each customer's first name including the payment_id
# %sql SELECT c.first_name, p1.payment_id, p1.customer_id, p1.amount FROM payment p1 LEFT JOIN customer c ON c.customer_id = p1.customer_id WHERE\
amount =(SELECT MAX(amount) FROM payment p2 WHERE p1.customer_id = p2.customer_id)
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 13 rows affected.
# [('MARY', 5, 1, Decimal('9.99')),
#  ('PATRICIA', 44, 2, Decimal('10.99')),
#  ('LINDA', 69, 3, Decimal('10.99')),
#  ('BARBARA', 101, 4, Decimal('8.99')),
#  ('ELIZABETH', 137, 5, Decimal('9.99')),
#  ('JENNIFER', 157, 6, Decimal('7.99')),
#  ('JENNIFER', 170, 6, Decimal('7.99')),
#  ('MARIA', 188, 7, Decimal('8.99')),
#  ('MARIA', 201, 7, Decimal('8.99')),
#  ('SUSAN', 224, 8, Decimal('9.99')),
#  ('MARGARET', 234, 9, Decimal('7.99')),
#  ('MARGARET', 252, 9, Decimal('7.99')),
#  ('DOROTHY', 263, 10, Decimal('7.99'))]

# %%
#Let's solve a couple of questions  and recap all the things that we have gone through

# %%
#Task: Create a list of all the different (distinct) replacement costs of the films.
# %sql SELECT DISTINCT(MIN(replacement_cost)) AS Min FROM film
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('9.99'),)]

# %%
#Write a query that gives an overview of how many films have replacements costs in the following cost ranges
#low: 9.99 - 19.99
#medium: 20.00 - 24.99
#high: 25.00 - 29.99
 
# %sql SELECT\
CASE WHEN replacement_cost BETWEEN 9.99 AND 19.99 THEN 'Low'\
WHEN replacement_cost BETWEEN 20.00 AND 24.99 THEN 'Medium'\
WHEN replacement_cost BETWEEN 25.00 AND 29.99 THEN 'High'\
END AS Level, COUNT(*) AS Count\
FROM film GROUP BY Level
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [('Medium', 46), ('Low', 78), ('High', 30)]

# %%
#Task: Create a list of the film titles including their title, length and category name ordered descendingly by the length. Filter the results to only the movies in the category 'Family','Games', 'Animation'.
#Question: In which category is the longest film and how long is it?

# %sql SELECT f1.title, c3.name, f1.length FROM film f1 INNER JOIN film_category f2 ON f1.film_id = f2.film_id\
INNER JOIN category c3 ON  f2.category_id = c3.category_id WHERE c3.name IN ('Family','Games', 'Animation') ORDER BY length DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 8 rows affected.
# [('BAKED CLEOPATRA', 'Family', 182),
#  ('ATLANTIS CAUSE', 'Family', 170),
#  ('AFRICAN EGG', 'Family', 130),
#  ('ARGONAUTS TOWN', 'Animation', 127),
#  ('AUTUMN CROW', 'Games', 108),
#  ('ANACONDA CONFESSIONS', 'Animation', 92),
#  ('APACHE DIVINE', 'Family', 92),
#  ('ALTER VICTORY', 'Animation', 57)]

# %%
 GROUP BY  c.name ORDER BY COUNT_OF_Names DESC

# %%
#Task: Create an overview of how many movies (titles) there are in each category (name).
#Question: Which category (name) is the most common among the films?

# %%
# %sql SELECT c.name, COUNT(c.name) AS COUNT_OF_Names FROM film f LEFT JOIN film_category fc\
ON f.film_id = fc.film_id LEFT JOIN\
category c ON fc.category_id = c.category_id GROUP BY  c.name ORDER BY COUNT_OF_Names DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 16 rows affected.
# [('Horror', 9),
#  ('Foreign', 5),
#  ('Family', 4),
#  ('Action', 4),
#  ('New', 4),
#  ('Sci-Fi', 4),
#  ('Sports', 3),
#  ('Music', 3),
#  ('Animation', 3),
#  ('Documentary', 2),
#  ('Comedy', 2),
#  ('Classics', 2),
#  ('Drama', 1),
#  ('Games', 1),
#  ('Children', 1),
#  (None, 0)]

# %%
 
#Task: Create an overview of the actors first and last names and in  how many movies they appear.
#Question: Which actor is part of most movies? 
# %sql SELECT a.first_name, a.last_name, COUNT(*) AS count FROM actor a INNER JOIN film_actor fa\
ON a.actor_id = fa.actor_id LEFT JOIN film f\
ON fa.film_id = f.film_id WHERE f.title IS NOT NULL GROUP BY a.first_name, a.last_name ORDER BY count DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [('NICK', 'WAHLBERG', 6), ('PENELOPE', 'GUINESS', 5)]

# %%
#Create an overview of the addresses that are not associated to any customer.
#How many addresses are that?
# %sql SELECT COUNT(*) AS COUNT FROM address a LEFT JOIN customer c ON  a.address_id = c.address_id WHERE c.customer_id IS  NULL
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(19,)]

# %%
#Task: Create an overview of the cities and how much sales (sum of amount) have occured there.
#Question: Which city has the most sales?
#Answer: Cape Coral with a total amount of 221.55
#city  - sum 
# %sql SELECT c.city, a.city_id, c_s.customer_id, SUM(amount) AS AMOUNT  FROM city c LEFT JOIN address a ON c.city_id = a.city_id\
INNER JOIN customer c_s ON c_s.address_id = a.address_id INNER JOIN payment p ON c_s.customer_id = p.customer_id\
WHERE a.city_id IS NOT NULL GROUP BY c_s.customer_id ORDER BY AMOUNT DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [('Athenai', 38, 3, Decimal('135.74')), ('Bhopal', 76, 15, Decimal('44.89'))]

# %%
#Task: Create an overview of the revenue (sum of amount) grouped by a column in the format "country, city".
#Question: Which country, city has the least sales?
#Answer: United States, Tallahassee with a total amount of 50.85.

# %%
# %sql SELECT co.country, c_c.city, SUM(p.amount) AS Sum  FROM payment p\
LEFT JOIN customer c ON p.customer_id = c.customer_id\
LEFT JOIN address a ON c.address_id = a.address_id\
LEFT JOIN city c_c ON a.city_id = c_c.city_id LEFT JOIN country co\
ON c_c.country_id = co.country GROUP BY co.country, c_c.city ORDER BY 3 DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 3 rows affected.
# [(None, None, Decimal('1165.14')),
#  (None, 'Athenai', Decimal('135.74')),
#  (None, 'Bhopal', Decimal('44.89'))]

# %%
#Task: Create a list with the average of the sales amount each staff_id has per customer.
#Question: Which staff_id makes in average more revenue per customer?
#Answer: staff_id 2 with an average revenue of 56.64 per customer.

# %%
# %sql SELECT s.staff_id, c.customer_id, SUM(p.amount) AS Sum FROM staff s LEFT JOIN customer c ON s.store_id = c.store_id\
INNER JOIN payment p ON c.customer_id = p.customer_id  GROUP BY s.staff_id, customer_id ORDER BY Sum DESC
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 15 rows affected.
# [(1, 7, Decimal('151.67')),
#  (1, 5, Decimal('144.62')),
#  (1, 3, Decimal('135.74')),
#  (1, 2, Decimal('128.73')),
#  (1, 1, Decimal('118.68')),
#  (2, 6, Decimal('93.72')),
#  (2, 8, Decimal('92.76')),
#  (2, 9, Decimal('89.77')),
#  (2, 4, Decimal('81.78')),
#  (1, 17, Decimal('74.86')),
#  (2, 16, Decimal('65.85')),
#  (1, 47, Decimal('47.90')),
#  (1, 10, Decimal('46.87')),
#  (1, 15, Decimal('44.89')),
#  (1, 48, Decimal('27.93'))]

# %%
# %sql SELECT  staff_id, ROUND(AVG(total), 2) AS AVG FROM\
(SELECT staff_id, customer_id, SUM(amount) total FROM payment GROUP BY staff_id, customer_id ORDER BY total DESC)\
sub GROUP BY staff_id
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 2 rows affected.
# [(1, Decimal('45.95')), (2, Decimal('43.76'))]

# %%
#Task: Create a query that shows average daily revenue of all Sundays.
#Question: What is the daily average revenue of all Sundays?

# %sql SELECT  ROUND(AVG(total),1) AS AVG FROM\
(SELECT DATE(payment_date), WEEKDAY(payment_date), SUM(amount) total\
FROM payment WHERE WEEKDAY(payment_date) = 0 GROUP BY DATE(payment_date), WEEKDAY(payment_date)) sub
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 1 rows affected.
# [(Decimal('37.5'),)]

# %%
# Make a list of movies - with their length and their replacement cost - that are longer than the average length in each replacement cost group.
# Which two movies are the shortest in that list and how long are they?
 
    
#%sql SELECT  AVG(length) FROM film  
# %sql SELECT title, replacement_cost, length FROM film f1 WHERE length >\
(SELECT  AVG(length) FROM film f2 WHERE f2.replacement_cost = f1.replacement_cost)  ORDER BY 3 DESC LIMIT 10
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 10 rows affected.
# [('CHICAGO NORTH', Decimal('11.99'), 185),
#  ('CATCH AMISTAD', Decimal('10.99'), 183),
#  ('BAKED CLEOPATRA', Decimal('20.99'), 182),
#  ('ANALYZE HOOSIERS', Decimal('19.99'), 181),
#  ('ALLEY EVOLUTION', Decimal('23.99'), 180),
#  ('CAUSE DATE', Decimal('16.99'), 179),
#  ('CASUALTIES ENCINO', Decimal('16.99'), 179),
#  ('BORN SPINAL', Decimal('17.99'), 179),
#  ('ANONYMOUS HUMAN', Decimal('12.99'), 179),
#  ('BRAVEHEART HUMAN', Decimal('14.99'), 176)]

# %%
#Task: Create a list that shows how much the average customer spent in total (customer life-time value) grouped by the different districts.
#Question: Which district has the highest average customer life-time value?

# %%
# %sql SELECT  DISTRICT FROM address
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 220 rows affected.
# [(' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
#  (' ',),
# ...

# %%
#Repeat by practice again using your phone

# %%
# %sql SELECT * FROM payment
# Out:
#  * mysql+mysqldb://root:***@127.0.0.1:3306/sql_advanced
# 323 rows affected.
# [(1, 1, 1, 76, Decimal('2.99'), datetime.datetime(2005, 5, 25, 11, 30, 37), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (2, 1, 1, 573, Decimal('0.99'), datetime.datetime(2005, 5, 28, 10, 35, 23), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (3, 1, 1, 1185, Decimal('5.99'), datetime.datetime(2005, 6, 15, 0, 54, 12), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (4, 1, 2, 1422, Decimal('0.99'), datetime.datetime(2005, 6, 15, 18, 2, 53), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (5, 1, 2, 1476, Decimal('9.99'), datetime.datetime(2005, 6, 15, 21, 8, 46), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (6, 1, 1, 1725, Decimal('4.99'), datetime.datetime(2005, 6, 16, 15, 18, 57), datetime.datetime(2006, 2, 15, 22, 12, 30)),
#  (7, 1, 1, 2308, Decimal('4.99'), datetime.datetime(2005, 6, 18, 8, 41, 48), datetime.datetime(2006, 2, 15, 22, 12, 30)),
# ...
